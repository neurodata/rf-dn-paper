# %% [markdown]
# # SMAC Search for Vision

# %%
from toolbox import *
import warnings
import argparse
import random
import os
import pandas as pd
import numpy as np
import cv2
import librosa
import time
import re
from timeout_decorator import timeout
import json

import matplotlib.pyplot as plt
import numpy as np
from ConfigSpace import (
    Categorical,
    Configuration,
    ConfigurationSpace,
    EqualsCondition,
    Float,
    InCondition,
    Integer,
)

import torchvision.models as models
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from sklearn.datasets import load_digits
from sklearn.model_selection import StratifiedKFold
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import cohen_kappa_score, accuracy_score
import xgboost as xgb

from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from skopt.callbacks import DeadlineStopper

from smac import MultiFidelityFacade as MFFacade
from smac import Scenario
from smac.facade import AbstractFacade
from smac.intensifier.hyperband import Hyperband
from smac.intensifier.successive_halving import SuccessiveHalving

import torch
import torch.nn as nn
import torchvision.models as models
import torch.nn.functional as F
from torch.utils.data import Dataset
import torch.optim as optim
import torchaudio
import torchaudio.transforms as trans
import re

from line_profiler import LineProfiler
from pathlib import Path


warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# /home/ziyan/miniconda3/envs/NeuroData/lib/python3.9/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /home/ziyan/miniconda3/envs/NeuroData/lib/python3.9/site-packages/torch/cuda/__init__.py:749: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() if nvml_count < 0 else nvml_count

# %%
def combinations_45(iterable, r):
    """Extracts 45 combinations from given list"""
    pool = tuple(iterable)
    n = len(pool)
    if r > n:
        return
    indices = list(range(r))
    yield tuple(pool[i] for i in indices)
    count = 0
    while count < 44:
        count += 1
        for i in reversed(range(r)):
            if indices[i] != i + n - r:
                break
        else:
            return
        indices[i] += 1
        for j in range(i + 1, r):
            indices[j] = indices[j - 1] + 1
        yield tuple(pool[i] for i in indices)

torch.multiprocessing.freeze_support()
n_classes = 3 # number of classes
samples_space = np.geomspace(10, 9000, num=8, dtype=int)
nums = list(range(10))
random.shuffle(nums)
classes_space = list(combinations_45(nums, n_classes))
normalize = lambda x: x / 255.0

cifar_trainset = datasets.CIFAR10(
    root="./", train=True, download=True, transform=None
)
cifar_train_images = normalize(cifar_trainset.data)
cifar_train_labels = np.array(cifar_trainset.targets)

cifar_testset = datasets.CIFAR10(
    root="./", train=False, download=True, transform=None
)
cifar_test_images = normalize(cifar_testset.data)
cifar_test_labels = np.array(cifar_testset.targets)

# cifar_train_images = cifar_train_images.reshape(-1, 32 * 32 * 3)
# cifar_test_images = cifar_test_images.reshape(-1, 32 * 32 * 3)

images = np.concatenate((cifar_train_images, cifar_test_images))
labels = np.concatenate((cifar_train_labels, cifar_test_labels))

indices = np.arange(images.shape[0])
np.random.shuffle(indices)
images = images[indices]
labels = labels[indices]

train_images, test_valid_images, train_labels, test_valid_labels = train_test_split(
    images, labels, test_size=0.5, random_state=317
)

test_images, valid_images, test_labels, valid_labels = train_test_split(
    test_valid_images, test_valid_labels, test_size=0.5, random_state=317
)

train_x = train_images
train_y = train_labels
test_x = test_images
test_y = test_labels
valid_x = valid_images
valid_y = valid_labels
test_valid_x = test_valid_images
test_valid_y = test_valid_labels
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# print(len(classes_space[0]))

# %%
class SimpleCNN32Filter(nn.Module):
    """
    Defines a simple CNN arhcitecture with 1 layer
    """

    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=10, stride=2)
        self.fc1 = nn.Linear(12 * 12 * 32, num_classes)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = x.view(-1, 144 * 32)
        x = self.fc1(x)
        return x


class SimpleCNN32Filter2Layers(nn.Module):
    """
    Define a simple CNN arhcitecture with 2 layers
    """

    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=5, stride=1)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.fc1 = nn.Linear(12 * 12 * 32, 100)
        self.fc2 = nn.Linear(100, num_classes)

    def forward(self, x):
        b = x.shape[0]
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(b, -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


class SimpleCNN32Filter5Layers(nn.Module):
    """
    Define a simple CNN arhcitecture with 5 layers
    """

    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(12 * 12 * 128, 200)
        self.fc2 = nn.Linear(200, num_classes)
        self.maxpool = nn.MaxPool2d((2, 2))
        self.bn = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)

    def forward(self, x):
        b = x.shape[0]
        x = F.relu(self.bn(self.conv1(x)))
        x = F.relu(self.bn(self.conv2(x)))
        x = self.maxpool(x)
        x = F.relu(self.bn2(self.conv3(x)))
        x = F.relu(self.bn2(self.conv4(x)))
        x = F.relu(self.bn3(self.conv5(x)))
        x = self.maxpool(x)
        x = x.view(b, -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

class SimpleCNN32Filter10Layers(nn.Module):
    """
    Define a simple CNN arhcitecture with 10 layers
    """

    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(12 * 12 * 512, 200)
        self.fc2 = nn.Linear(200, num_classes)
        self.maxpool = nn.MaxPool2d((2, 2))
        self.bn = BatchNorm2d(32)
        self.bn2 = BatchNorm2d(64)
        self.bn3 = BatchNorm2d(128)
        self.bn4 = BatchNorm2d(256)
        self.bn5 = BatchNorm2d(512)

    def forward(self, x):
        b = x.shape[0]
        x = F.relu(self.bn(self.conv1(x)))
        x = F.relu(self.bn(self.conv2(x)))
        x = self.maxpool(x)
        x = F.relu(self.bn2(self.conv3(x)))
        x = F.relu(self.bn2(self.conv4(x)))
        x = self.maxpool(x)
        x = F.relu(self.bn3(self.conv5(x)))
        x = F.relu(self.bn3(self.conv6(x)))
        x = self.maxpool(x)
        x = F.relu(self.bn4(self.conv7(x)))
        x = F.relu(self.bn4(self.conv8(x)))
        x = self.maxpool(x)
        x = F.relu(self.bn5(self.conv9(x)))
        x = F.relu(self.bn5(self.conv10(x)))
        x = self.maxpool(x)
        x = x.view(b, -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# CNN architectures
cnn32 = SimpleCNN32Filter(10)
cnn32_2l = SimpleCNN32Filter2Layers(10)
cnn32_5l = SimpleCNN32Filter5Layers(10)

# Resnet
resnet = models.resnet18(pretrained=True)
num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, 10)

# EfficientNet
# efnet = models.efficientnet_b0(pretrained=True)
# num_classes = 10
# efnet.classifier[1] = nn.Linear(efnet.classifier[1].in_features, num_classes)

# %% [markdown]
# # XGBT tuning

# %%
class XGBWrapper(BaseEstimator):
    def __init__(self, n_estimators=100, max_depth=2, seed= 317, min_child_weight=1, gamma=0.1, subsample=0.8, colsample_bytree=0.5, learning_rate=0.1, objective='multi:softprob', colsample_bylevel=0.5, colsample_bynode=0.5):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.seed= seed
        self.min_child_weight = min_child_weight
        self.gamma = gamma
        self.subsample = subsample
        self.colsample_bytree = colsample_bytree
        self.colsample_bylevel = colsample_bylevel
        self.colsample_bynode = colsample_bynode
        self.learning_rate = learning_rate
        self.objective = objective
        self.model = xgb.XGBClassifier(n_estimators=self.n_estimators, max_depth=self.max_depth, seed=self.seed, min_child_weight=self.min_child_weight, gamma=self.gamma, subsample=self.subsample, colsample_bytree=self.colsample_bytree, colsample_bylevel=self.colsample_bylevel, colsample_bynode=self.colsample_bynode ,learning_rate=self.learning_rate, objective=self.objective)

    @property
    def configspace(self) -> ConfigurationSpace:
        cs = ConfigurationSpace()
        n_estimators = Integer("n_estimators", (100, 1200), default=100)
        max_depth = Integer("max_depth", (2, 21), default=2)
        min_child_weight = Integer("min_child_weight", (1, 10), default=1)
        gamma = Float("gamma", (0.1, 1.0), default=0.1)
        subsample = Float("subsample", (0.5, 1.0), default=0.8)
        colsample_bytree = Float("colsample_bytree", (0.3, 1.0), default=0.6)
        colsample_bylevel = Float("colsample_bylevel", (0.3, 1.0), default=0.6)
        colsample_bynode = Float("colsample_bynode", (0.3, 1.0), default=0.6)
        learning_rate = Float("learning_rate", (0.001, 0.3), default=0.1)
        cs.add_hyperparameters([n_estimators, max_depth, min_child_weight, gamma, subsample, colsample_bytree, colsample_bylevel, colsample_bynode, learning_rate])
        return cs
    
    def fit(self, config: Configuration, seed: int = 0, budget: int = 250) -> float: 
        config = dict(config)  
        self.model.set_params(**config)
        X = train_x
        y = train_y
        X = X.reshape(X.shape[0], -1)
        
        scores = cross_val_score(self.model, X, y, cv=5)
        return 1 - np.mean(scores)
    

def plot_trajectory(facades: list[AbstractFacade], BO_file = None) -> None:
    """Plots the trajectory (incumbents) of the optimization process."""
    plt.figure()
    plt.title("Trajectory")
    plt.xlabel("Wallclock time [s]")
    # print(len(facades))
    plt.ylabel("Accuracy")
    print("\nfacades[0]:", facades[0].scenario)


    for facade in facades:
        X, Y = [], []
        for item in facade.intensifier.trajectory:
            # Single-objective optimization
            assert len(item.config_ids) == 1
            assert len(item.costs) == 1
            # print(1 - round(item.costs[0], 3))
            y = item.costs[0]
            x = item.walltime
            print(type(item.costs[0]), item.costs[0])
            X.append(x)
            Y.append(1-y)

        plt.plot(X, Y, label=facade.intensifier.__class__.__name__)
        plt.scatter(X, Y, marker="o")

    if BO_file:
        with open(BO_file, "r") as f:
            data = f.readlines()
        bo_accuracy, bo_kappa, bo_ece, bo_time = [], [], [], []

        # Parse the data
        for line in data:
            # Using regular expression to find all the floating point numbers in each line
            if "Time: " in line:
                numbers = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                if numbers:
                    bo_accuracy.append(float(numbers[0]))
                    bo_kappa.append(float(numbers[1]))
                    bo_ece.append(float(numbers[2]))
                    bo_time.append(float(numbers[3]))

        max_bo_accs = np.maximum.accumulate(bo_accuracy)
        bo_cum_time = np.cumsum(bo_time)
        plt.plot(bo_cum_time, max_bo_accs, label='Max BO Accuracies', marker='x')
    

    plt.legend()
    plt.show()

# %%
@timeout(21600)
def main():
    GBT = XGBWrapper()

    facades: list[AbstractFacade] = []
    for intensifier_object in [Hyperband]:

        scenario = Scenario(
            GBT.configspace,
            walltime_limit=21600,
            output_directory=Path("smac_hyperband_output_budget_6hr_XGBT"),
            n_trials=10000,
            min_budget=100,
            max_budget=1000,
            n_workers=1,

        )

        initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
        intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")

        smac = MFFacade(
            scenario,
            GBT.fit,
            initial_design=initial_design,
            intensifier=intensifier,
            overwrite=True,
        )

        print("optimiizing")
        print(type(smac), "|", smac)
        incumbent = smac.optimize()
        print("incumbent:", incumbent)
        default_cost = smac.validate(GBT.configspace.get_default_configuration())
        print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")
        incumbent_cost = smac.validate(incumbent)
        print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")

        facades.append(smac)
        for arrt in dir(smac):
            if not arrt.startswith("_"):
                print(arrt, getattr(smac, arrt))

    print("facades:", facades)
    BO_file = None
    plot_trajectory(facades, BO_file)


if __name__ == "__main__":
    # with open('smac_results_2h.txt', "w") as f:
    #     pass
    profiler = LineProfiler()
    profiler.add_function(main)
    profiler.enable()

    main()

    profiler.disable()
    profiler.print_stats()
# Out:
# [INFO][abstract_initial_design.py:147] Using 5 initial design configurations and 0 additional configurations.
# optimiizing
# <class 'smac.facade.multi_fidelity_facade.MultiFidelityFacade'> | <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fde384d8a60>
# [INFO][successive_halving.py:164] Successive Halving uses budget type BUDGETS with eta 3, min budget 100, and max budget 1000.
# [INFO][successive_halving.py:323] Number of configs in stage:
# [INFO][successive_halving.py:325] --- Bracket 0: [9, 3, 1]
# [INFO][successive_halving.py:325] --- Bracket 1: [5, 1]
# [INFO][successive_halving.py:325] --- Bracket 2: [3]
# [INFO][successive_halving.py:327] Budgets in stage:
# [INFO][successive_halving.py:329] --- Bracket 0: [111.1111111111111, 333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 1: [333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 2: [1000.0]
# Exception ignored on calling ctypes callback function: <bound method DataIter._next_wrapper of <xgboost.data.SingleBatchInternalIter object at 0x7fde60d4f5e0>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/xgboost/core.py", line 588, in _next_wrapper
#     def _next_wrapper(self, this: None) -> int:  # pylint: disable=unused-argument
# KeyboardInterrupt:

# %% [markdown]
# # RF tuning

# %%
class RFWrapper(BaseEstimator):
    def __init__(self, n_estimators=100, max_depth=2, random_state=317, min_samples_split=2, min_samples_leaf=1, max_features=None, criterion="gini", max_samples = 0.5):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.random_state = random_state
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf
        self.max_features = max_features   
        self.criterion = "gini"
        self.max_samples = max_samples
        self.model = RandomForestClassifier(n_estimators=self.n_estimators, max_depth=self.max_depth, random_state=self.random_state, min_samples_split=self.min_samples_split, min_samples_leaf=self.min_samples_leaf, criterion=self.criterion, max_features=self.max_features, max_samples=self.max_samples)

    @property
    def configspace(self) -> ConfigurationSpace:
        cs = ConfigurationSpace()
        n_estimators = Integer("n_estimators", (100, 1200), default=100)
        max_depth = Integer("max_depth", (2,21), default=2)
        min_samples_split = Integer("min_samples_split", (2, 20), default=2)
        min_samples_leaf = Integer("min_samples_leaf", (1, 20), default=1)
        criterion = Categorical("criterion", ["gini", "entropy", "log_loss"], default="gini")
        max_features = Categorical("max_features", ["sqrt", "log2", "None"], default="None")
        max_samples = Float("max_samples", (0.1, 0.99), log=True)
        cs.add_hyperparameters([n_estimators, max_depth, min_samples_split, min_samples_leaf, criterion, max_features, max_samples])
        return cs
    
    def fit(self, config: Configuration, seed: int = 0, budget: int = 250) -> float: 
        config = dict(config)  
        if config['max_features'] == 'None':
            config['max_features'] = None
        self.model.set_params(**config)
        X = train_x
        y = train_y
        X = X.reshape(X.shape[0], -1)
        
        scores = cross_val_score(self.model, X, y, cv=5)
        return 1 - np.mean(scores)
    

def plot_trajectory(facades: list[AbstractFacade], BO_file = None) -> None:
    """Plots the trajectory (incumbents) of the optimization process."""
    plt.figure()
    plt.title("Trajectory")
    plt.xlabel("Wallclock time [s]")
    # print(len(facades))
    plt.ylabel("Accuracy")
    print("\nfacades[0]:", facades[0].scenario)


    for facade in facades:
        X, Y = [], []
        for item in facade.intensifier.trajectory:
            # Single-objective optimization
            assert len(item.config_ids) == 1
            assert len(item.costs) == 1
            # print(1 - round(item.costs[0], 3))
            y = item.costs[0]
            x = item.walltime
            print(type(item.costs[0]), item.costs[0])
            X.append(x)
            Y.append(1-y)

        plt.plot(X, Y, label=facade.intensifier.__class__.__name__)
        plt.scatter(X, Y, marker="o")

    if BO_file:
        with open(BO_file, "r") as f:
            data = f.readlines()
        bo_accuracy, bo_kappa, bo_ece, bo_time = [], [], [], []

        # Parse the data
        for line in data:
            # Using regular expression to find all the floating point numbers in each line
            if "Time: " in line:
                numbers = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                if numbers:
                    bo_accuracy.append(float(numbers[0]))
                    bo_kappa.append(float(numbers[1]))
                    bo_ece.append(float(numbers[2]))
                    bo_time.append(float(numbers[3]))

        max_bo_accs = np.maximum.accumulate(bo_accuracy)
        bo_cum_time = np.cumsum(bo_time)
        plt.plot(bo_cum_time, max_bo_accs, label='Max BO Accuracies', marker='x')
    

    plt.legend()
    plt.show()

# %%
@timeout(21600)
def main():
    RF = RFWrapper()

    facades: list[AbstractFacade] = []
    for intensifier_object in [Hyperband]:

        scenario = Scenario(
            RF.configspace,
            walltime_limit=21600,
            output_directory=Path("smac_hyperband_output_budget_6hr_RF"),
            n_trials=10000,
            min_budget=100,
            max_budget=1000,
            n_workers=4,

        )

        initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
        intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")

        smac = MFFacade(
            scenario,
            RF.fit,
            initial_design=initial_design,
            intensifier=intensifier,
            overwrite=True,
        )

        print("optimiizing")
        print(type(smac), "|", smac)
        incumbent = smac.optimize()
        print("incumbent:", incumbent)
        default_cost = smac.validate(RF.configspace.get_default_configuration())
        print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")
        incumbent_cost = smac.validate(incumbent)
        print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")

        facades.append(smac)
        for arrt in dir(smac):
            if not arrt.startswith("_"):
                print(arrt, getattr(smac, arrt))

    print("facades:", facades)
    BO_file = None
    plot_trajectory(facades, BO_file)


if __name__ == "__main__":
    # with open('smac_results_2h.txt', "w") as f:
    #     pass
    profiler = LineProfiler()
    profiler.add_function(main)
    profiler.enable()

    main()

    profiler.disable()
    profiler.print_stats()
# Out:
# [INFO][abstract_initial_design.py:82] Using `n_configs` and ignoring `n_configs_per_hyperparameter`.
# [INFO][abstract_initial_design.py:147] Using 5 initial design configurations and 0 additional configurations.
# optimiizing
# <class 'smac.facade.multi_fidelity_facade.MultiFidelityFacade'> | <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7968bb0>
# [INFO][successive_halving.py:164] Successive Halving uses budget type BUDGETS with eta 3, min budget 100, and max budget 1000.
# [INFO][successive_halving.py:323] Number of configs in stage:
# [INFO][successive_halving.py:325] --- Bracket 0: [9, 3, 1]
# [INFO][successive_halving.py:325] --- Bracket 1: [5, 1]
# [INFO][successive_halving.py:325] --- Bracket 2: [3]
# [INFO][successive_halving.py:327] Budgets in stage:
# [INFO][successive_halving.py:329] --- Bracket 0: [111.1111111111111, 333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 1: [333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 2: [1000.0]
# [INFO][smbo.py:319] Finished 0 trials.
# [INFO][smbo.py:319] Finished 0 trials.
# [INFO][smbo.py:319] Finished 0 trials.
# [INFO][smbo.py:319] Finished 0 trials.
# 2024-05-13 12:57:35,646 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_wrapper-a726a74b6ad0ee991dafee5753b67103')" coro=<Worker.execute() done, defined at /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-13 12:57:35,646 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_wrapper-f2d2d565ae9bc191807118b67db89710')" coro=<Worker.execute() done, defined at /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-13 12:57:35,646 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_wrapper-42624ed233b4b634f44ec876e1aeee14')" coro=<Worker.execute() done, defined at /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-05-13 12:57:35,648 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_wrapper-fd22cd75b70061c41251919ad446efde')" coro=<Worker.execute() done, defined at /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 56
#      53 profiler.add_function(main)
#      54 profiler.enable()
# ---> 56 main()
#      58 profiler.disable()
#      59 profiler.print_stats()
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/timeout_decorator/timeout_decorator.py:82, in timeout.<locals>.decorate.<locals>.new_function(*args, **kwargs)
#      79     return function(*args, **kwargs)
#      81 try:
# ---> 82     return function(*args, **kwargs)
#      83 finally:
#      84     if new_seconds:
#
# Cell In[20], line 32, in main()
#      30 print("optimiizing")
#      31 print(type(smac), "|", smac)
# ---> 32 incumbent = smac.optimize()
#      33 print("incumbent:", incumbent)
#      34 default_cost = smac.validate(RF.configspace.get_default_configuration())
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/smac/facade/abstract_facade.py:319, in AbstractFacade.optimize(self, data_to_scatter)
#     316     raise ValueError("data_to_scatter must be None or dict with some elements, but got an empty dict.")
#     318 try:
# --> 319     incumbents = self._optimizer.optimize(data_to_scatter=data_to_scatter)
#     320 finally:
#     321     self._optimizer.save()
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/smac/main/smbo.py:304, in SMBO.optimize(self, data_to_scatter)
#     300     trial_info = self.ask()
#     302     # We submit the trial to the runner
#     303     # In multi-worker mode, SMAC waits till a new worker is available here
# --> 304     self._runner.submit_trial(trial_info=trial_info, **dask_data_to_scatter)
#     305 except StopIteration:
#     306     self._stop = True
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/smac/runner/dask_runner.py:130, in DaskParallelRunner.submit_trial(self, trial_info, **dask_data_to_scatter)
#     128 if self.count_available_workers() <= 0:
#     129     logger.debug("No worker available. Waiting for one to be available...")
# --> 130     wait(self._pending_trials, return_when="FIRST_COMPLETED")
#     131     self._process_pending_trials()
#     133 # Check again to make sure that there are resources
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/client.py:5444, in wait(fs, timeout, return_when)
#    5442     timeout = parse_timedelta(timeout, default="s")
#    5443 client = default_client()
# -> 5444 result = client.sync(_wait, fs, timeout=timeout, return_when=return_when)
#    5445 return result
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/utils.py:358, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     356     return future
#     357 else:
# --> 358     return sync(
#     359         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     360     )
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/utils.py:431, in sync(loop, func, callback_timeout, *args, **kwargs)
#     429 else:
#     430     while not e.is_set():
# --> 431         wait(10)
#     433 if error is not None:
#     434     raise error
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/utils.py:420, in sync.<locals>.wait(timeout)
#     418 def wait(timeout: float | None) -> bool:
#     419     try:
# --> 420         return e.wait(timeout)
#     421     except KeyboardInterrupt:
#     422         loop.add_callback(cancel)
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File /opt/anaconda3/envs/NeuroData/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# 2024-05-13 12:57:37,860 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2024-05-13 12:57:37,862 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2024-05-13 12:57:37,866 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
#     self.run_forever()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 1869, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/selectors.py", line 562, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
#     self.run_forever()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 1869, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/selectors.py", line 562, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
#     self.run_forever()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 1869, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/selectors.py", line 562, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# 2024-05-13 12:57:37,883 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
#     self.run_forever()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/asyncio/base_events.py", line 1869, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/opt/anaconda3/envs/NeuroData/lib/python3.9/selectors.py", line 562, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
# KeyboardInterrupt
# 2024-05-13 12:57:54,025 - distributed.nanny - WARNING - Worker process still alive after 3.2 seconds, killing
# 2024-05-13 12:57:54,027 - distributed.nanny - WARNING - Worker process still alive after 3.1999981689453127 seconds, killing
# 2024-05-13 12:57:54,028 - distributed.nanny - WARNING - Worker process still alive after 3.2 seconds, killing
# 2024-05-13 12:57:54,032 - distributed.nanny - WARNING - Worker process still alive after 3.1999992370605472 seconds, killing

# %% [markdown]
# # DN tuning

# %%
# train_tensor = torch.tensor(train_images, dtype=torch.float32)
# train_labels_tensor = torch.tensor(train_labels, dtype=torch.long)
# test_tensor = torch.tensor(test_images, dtype=torch.float32)
# test_labels_tensor = torch.tensor(test_labels, dtype=torch.long)
# valid_tensor = torch.tensor(valid_images, dtype=torch.float32)
# valid_labels_tensor = torch.tensor(valid_labels, dtype=torch.long)

# train_dataset = torch.utils.data.TensorDataset(train_tensor, train_labels_tensor)
# test_dataset = torch.utils.data.TensorDataset(test_tensor, test_labels_tensor)
# valid_dataset = torch.utils.data.TensorDataset(valid_tensor, valid_labels_tensor)

# train_loader = DataLoader(train_dataset, batch_size=batch, shuffle=True, num_workers=4)
# test_loader = DataLoader(test_dataset, batch_size=batch, shuffle=False, num_workers=4)
# valid_loader = DataLoader(valid_dataset, batch_size=batch, shuffle=False, num_workers=4)

# %%
# For CNN 
data_transforms = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
    )

# %%
class CNN32Wrapper(BaseEstimator):
    def __init__(self, criterion = nn.CrossEntropyLoss()):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = cnn32.to(self.device)
        self.criterion = criterion
        self.lr = None
        self.batch_size = None
        self.epochs = None
        self.optimizer = None

    @property
    def configspace(self)-> ConfigurationSpace:
        cs = ConfigurationSpace()
        lr_init = Float("lr_init", (0.00001, 0.1), log=True)
        learning_rate = Categorical("learning_rate", ["constant", "invscaling", "adaptive"], default="constant")
        solver = Categorical("solver", ["sgd", "adam"])
        batch_size = Integer("batch_size", (16, 1024))
        epochs = Integer("epochs", (30, 160))
        cs.add_hyperparameters([lr_init, learning_rate, solver, batch_size, epochs])

        use_lr = EqualsCondition(child=learning_rate, parent=solver, value="sgd")
        cs.add_conditions([use_lr])

        weight_decay = Float("weight_decay", (0.0001, 0.1), log=True)
        momentum = Float("momentum", (0, 0.99))
        dampening = Float("dampening", (0, 0.99))
        cs.add_hyperparameters([weight_decay, momentum, dampening])

        weight_decay_condition = InCondition(child=weight_decay, parent=solver, values=["sgd", "adam"])
        momentum_condition = InCondition(child=momentum, parent=solver, values=["sgd"])
        dampening_condition = InCondition(child=dampening, parent=solver, values=["sgd"])
        cs.add_conditions([use_lr, weight_decay_condition, momentum_condition, dampening_condition])

        return cs
    
    def fit(self, config: Configuration, seed: int = 0, budget: int = 250) -> float: 
        self.trial_start_time = time.perf_counter()

        print("Config:", config)
        # print(time.time())
        epoch_start_timer = time.perf_counter()
        # print("okay here?")
        max_epochs = [0]
        # print("what abt here?")

        X = torch.tensor(train_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        y = torch.tensor(train_y, dtype=torch.long)
        valid_x_inFit = torch.tensor(valid_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        valid_y_inFit = torch.tensor(valid_y, dtype=torch.long)


        # ### only for resnet:
        # X = X.repeat(1, 3, 1, 1)
        # valid_x_inFit = valid_x_inFit.repeat(1, 3, 1, 1)


        # print("so far so good")
        # print("Model:", self.model)
        model = self.model
        # print("break1")
        # print("Criterion:", self.criterion)
        criterion = self.criterion

        self.lr = config.get('lr_init')
        # print("lr:", self.lr)
        self.epochs = config.get('epochs')
        # print("epochs:", self.epochs)
        self.batch_size = config.get('batch_size')
        # print("batch_size:", self.batch_size)
        # print("solver type:", type(self.sovler))
        solver_name = config.get('solver', 'sgd')
        # print("solver_name:", solver_name, type(solver_name))
        momentum = config.get('momentum', 0.9)
        weight_decay = config.get('weight_decay', 0.9)
        dampening = config.get('dampening', 0.9)
        print("is sgd:", solver_name=='sgd', "| is adam:", solver_name=='adam')
        # print(self.model.parameters())
        if solver_name == 'sgd':
            # optimizer_args = {
            #     'lr': self.lr,
            #     'momentum': config.get('momentum', 0),
            #     'weight_decay': config.get('weight_decay', 0),
            #     'dampening': config.get('dampening', 0)
            # }
            self.optimizer = optim.SGD(self.model.parameters(), lr=self.lr, momentum=momentum, weight_decay=weight_decay, dampening=dampening)

        elif solver_name == 'adam':
            # optimizer_args = {
            #     'lr': self.lr,
            #     'weight_decay': config.get('weight_decay', 0) 
            # }
            self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr, weight_decay=weight_decay)

        else:
            raise ValueError(f"Unknown optimizer: {solver_name}")
        # print("solver type:", type(self.optimizer))
        # print("solver:", self.optimizer)
        prev_loss = float("inf")
        flag = 0

        for epoch in range(self.epochs):
            model.train()
            for i in range(0, len(X), self.batch_size):
                # print(type(X), type(y))
                inputs = X[i : i + self.batch_size].to(self.device)
                labels = y[i : i + self.batch_size].to(self.device)
                self.optimizer.zero_grad()
                if inputs.shape[0] <= 2:
                    continue
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()

            model.eval()
            cur_loss = 0
            with torch.no_grad():
                for i in range(0, len(valid_x_inFit), self.batch_size):
                    # get the inputs
                    inputs = valid_x_inFit[i : i + self.batch_size].to(self.device)
                    labels = valid_y_inFit[i : i + self.batch_size].to(self.device)
                    if inputs.shape[0] == 1:
                        inputs = torch.cat((inputs, inputs, inputs), dim = 0)
                        labels = torch.cat((labels, labels, labels), dim = 0)

                    # forward
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    cur_loss += loss
            # early stop if 3 epochs in a row no loss decrease
            # print(round(time.time()-epoch_start_timer, 2))
            # if time.perf_counter() - epoch_start_timer > budget:
            #     print(f"Stopping training early at epoch {epoch} due to time budget.")
            #     break  # Stop training if budget exceeded
            
            if cur_loss < prev_loss:
                prev_loss = cur_loss
                flag = 0
            else:
                flag += 1
                if flag >= 3:
                    max_epochs.append(epoch)
                    break

        # print(np.max(max_epochs))
        print("evaluating...")
        model.eval()
        with torch.no_grad():
            outputs = model(valid_x_inFit.to(self.device))
            _, predicted = torch.max(outputs.data, 1)
            predictions = predicted.cpu().numpy()
        acc = accuracy_score(valid_y, predictions)
        print("accuracy:", acc)

        self.trial_end_time = time.perf_counter()
        valid_probs = self.predict_proba(valid_x_inFit)
        valid_kappa = cohen_kappa_score(valid_y, predictions)
        valid_ece = get_ece(valid_probs, predictions, valid_y)
        with open('smac_results_2h.txt', "a") as f:
            f.write(f"Valid Accuracy: {acc}, Valid Kappa: {valid_kappa}, Valid ECE: {valid_ece}, Time: {self.trial_end_time - self.trial_start_time}\n")
            
        return 1-acc
    
    def predict_proba(self, X):
        # X = X.reshape(-1, 3, 32, 32)
        model = self.model
        model.eval()
        test_probs = []
        with torch.no_grad():
            outputs = model(X.to(self.device))
            test_prob = nn.Softmax(dim=1)(outputs)
            test_probs = test_prob.cpu().numpy()
            return test_probs
        
def plot_trajectory(facades: list[AbstractFacade], BO_file = None) -> None:
    """Plots the trajectory (incumbents) of the optimization process."""
    plt.figure()
    plt.title("Trajectory")
    plt.xlabel("Wallclock time [s]")
    # print(len(facades))
    plt.ylabel("Accuracy")
    print("\nfacades[0]:", facades[0].scenario)
    # print("\nfacades[1]:", facades[1].scenario)
    # plt.ylim(0, 0.4)

    for facade in facades:
        X, Y = [], []
        for item in facade.intensifier.trajectory:
            # Single-objective optimization
            assert len(item.config_ids) == 1
            assert len(item.costs) == 1
            # print(1 - round(item.costs[0], 3))
            y = item.costs[0]
            x = item.walltime
            print(type(item.costs[0]), item.costs[0])
            X.append(x)
            Y.append(1-y)

        plt.plot(X, Y, label=facade.intensifier.__class__.__name__)
        plt.scatter(X, Y, marker="o")

    if BO_file:
        with open(BO_file, "r") as f:
            data = f.readlines()
        bo_accuracy, bo_kappa, bo_ece, bo_time = [], [], [], []

        # Parse the data
        for line in data:
            # Using regular expression to find all the floating point numbers in each line
            if "Time: " in line:
                numbers = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                if numbers:
                    bo_accuracy.append(float(numbers[0]))
                    bo_kappa.append(float(numbers[1]))
                    bo_ece.append(float(numbers[2]))
                    bo_time.append(float(numbers[3]))

        max_bo_accs = np.maximum.accumulate(bo_accuracy)
        bo_cum_time = np.cumsum(bo_time)
        plt.plot(bo_cum_time, max_bo_accs, label='Max BO Accuracies', marker='x')
    

    plt.legend()
    plt.show()

# %%
from line_profiler import LineProfiler
from pathlib import Path
# @timeout(14400)
def main():

    
    CNN32 = CNN32Wrapper()

    facades: list[AbstractFacade] = []
    for intensifier_object in [Hyperband]:
        # Define our environment variables
        
        scenario = Scenario(
            CNN32.configspace,
            walltime_limit=21600,  # After 3600 seconds, we stop the hyperparameter optimization
            output_directory=Path("smac_hyperband_output_budget_6hr_CNN_1l"),
            n_trials=10000,  # Evaluate max 500 different trials
            min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
            # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
            max_budget=1000,  # only for CNN32_5layers, Resnet18
            n_workers=2,
        )


        
        # We want to run five random configurations before starting the optimization.
        initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
        
        # Create our intensifier
        intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
        
        # Create our SMAC object and pass the scenario and the train method
        smac = MFFacade(
            scenario,
            CNN32.fit,
            initial_design=initial_design,
            intensifier=intensifier,
            overwrite=True,
        )
        # print("I fitted!!!!!!!!!!!!!!:", smac)

        # Let's optimize
        print("optimizing...")
        print(type(smac), "|", smac)
        opt_start_time = time.time()
        incumbent = smac.optimize()
        opt_end_time = time.time()
        print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
        print("incumbent:", incumbent)
        # break
        # Get cost of default configuration
        default_cost = smac.validate(CNN32.configspace.get_default_configuration())
        print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")

        # Let's calculate the cost of the incumbent
        incumbent_cost = smac.validate(incumbent)
        print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
        print("appending...")
        facades.append(smac)
        for attr in dir(smac):
            if not attr.startswith('__'):
                print(attr, getattr(smac, attr))
    print("attempting to plot")
    # Let's plot it
    print("facades:", facades)
    # BO_file = "CNN32_5l_BO_results_2h.txt"
    plot_trajectory(facades)

if __name__ == "__main__":
    with open('smac_results_2h.txt', "w") as f:
        pass
    profiler = LineProfiler()
    profiler.add_function(main)
    profiler.enable()

    main()

    profiler.disable()
    profiler.print_stats()
# Out:
# [INFO][abstract_initial_design.py:147] Using 5 initial design configurations and 0 additional configurations.
# optimizing...
# <class 'smac.facade.multi_fidelity_facade.MultiFidelityFacade'> | <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>
# [INFO][successive_halving.py:164] Successive Halving uses budget type BUDGETS with eta 3, min budget 100, and max budget 1000.
# [INFO][successive_halving.py:323] Number of configs in stage:
# [INFO][successive_halving.py:325] --- Bracket 0: [9, 3, 1]
# [INFO][successive_halving.py:325] --- Bracket 1: [5, 1]
# [INFO][successive_halving.py:325] --- Bracket 2: [3]
# [INFO][successive_halving.py:327] Budgets in stage:
# [INFO][successive_halving.py:329] --- Bracket 0: [111.1111111111111, 333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 1: [333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 2: [1000.0]
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 569,
#   'dampening': 0.9688321588104364,
#   'epochs': 88,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.03832216850492789,
#   'momentum': 0.2619100559835807,
#   'solver': 'sgd',
#   'weight_decay': 0.007126995609048582,
# })
#
# is sgd: True | is adam: False
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 737,
#   'dampening': 0.7911669785745563,
#   'epochs': 69,
#   'learning_rate': 'constant',
#   'lr_init': 0.011423254155608374,
#   'momentum': 0.7664913525398744,
#   'solver': 'sgd',
#   'weight_decay': 0.006859416411328701,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4467333333333333
# Config: Configuration(values={
#   'batch_size': 624,
#   'epochs': 111,
#   'lr_init': 0.013680095279726922,
#   'solver': 'adam',
#   'weight_decay': 0.0070925432147358365,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.09846666666666666
# Config: Configuration(values={
#   'batch_size': 565,
#   'epochs': 117,
#   'lr_init': 0.07098936257405905,
#   'solver': 'adam',
#   'weight_decay': 0.06780227021579836,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3762666666666667
# evaluating...
# accuracy: 0.11513333333333334
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# Config: Configuration(values={
#   'batch_size': 378,
#   'dampening': 0.660099048291211,
#   'epochs': 69,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.024846338168982397,
#   'momentum': 0.2082787354631025,
#   'solver': 'sgd',
#   'weight_decay': 0.00024365700014641997,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.49273333333333336
# Config: Configuration(values={
#   'batch_size': 334,
#   'dampening': 0.9784900996786339,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.01381635682257479,
#   'momentum': 0.20678798853388633,
#   'solver': 'sgd',
#   'weight_decay': 0.000304739361773639,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.47126666666666667
# Config: Configuration(values={
#   'batch_size': 674,
#   'dampening': 0.15737988780906453,
#   'epochs': 53,
#   'learning_rate': 'constant',
#   'lr_init': 0.008562913278818234,
#   'momentum': 0.6497662935706207,
#   'solver': 'sgd',
#   'weight_decay': 0.0002597459914786609,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.32493333333333335
# evaluating...
# Config: Configuration(values={
#   'batch_size': 214,
#   'dampening': 0.8295654584238159,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.043851702560851274,
#   'momentum': 0.9666948703632617,
#   'solver': 'sgd',
#   'weight_decay': 0.002546558192892438,
# })
#
# is sgd: True | is adam: False
# accuracy: 0.4722
# Config: Configuration(values={
#   'batch_size': 393,
#   'epochs': 68,
#   'lr_init': 0.0010568850641642976,
#   'solver': 'adam',
#   'weight_decay': 0.01385362093494589,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.42446666666666666
# Config: Configuration(values={
#   'batch_size': 104,
#   'epochs': 32,
#   'lr_init': 0.0013416553240794976,
#   'solver': 'adam',
#   'weight_decay': 0.010605200554367014,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.46313333333333334
# Config: Configuration(values={
#   'batch_size': 300,
#   'epochs': 55,
#   'lr_init': 0.0016482880263230333,
#   'solver': 'adam',
#   'weight_decay': 0.008235243613754844,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.508
# Config: Configuration(values={
#   'batch_size': 602,
#   'dampening': 0.48868165636549615,
#   'epochs': 110,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.001840254140178233,
#   'momentum': 0.495,
#   'solver': 'sgd',
#   'weight_decay': 0.009696103902761146,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.47473333333333334
# Config: Configuration(values={
#   'batch_size': 351,
#   'dampening': 0.6092475865450772,
#   'epochs': 81,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.0018245825750494876,
#   'momentum': 0.5983387060013583,
#   'solver': 'sgd',
#   'weight_decay': 0.00043540659670259033,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4056
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3914666666666667
# Config: Configuration(values={
#   'batch_size': 674,
#   'dampening': 0.15737988780906453,
#   'epochs': 53,
#   'learning_rate': 'constant',
#   'lr_init': 0.008562913278818234,
#   'momentum': 0.6497662935706207,
#   'solver': 'sgd',
#   'weight_decay': 0.0002597459914786609,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.49273333333333336
# Config: Configuration(values={
#   'batch_size': 378,
#   'dampening': 0.660099048291211,
#   'epochs': 69,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.024846338168982397,
#   'momentum': 0.2082787354631025,
#   'solver': 'sgd',
#   'weight_decay': 0.00024365700014641997,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4722
# Config: Configuration(values={
#   'batch_size': 430,
#   'dampening': 0.20104436756131971,
#   'epochs': 58,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.003767446322363347,
#   'momentum': 0.7557957780677329,
#   'solver': 'sgd',
#   'weight_decay': 0.00040146872497356955,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4738
# evaluating...
# accuracy: 0.47126666666666667
# [INFO][abstract_intensifier.py:515] Added config b1f051 as new incumbent because there are no incumbents yet.
# Config: Configuration(values={
#   'batch_size': 806,
#   'epochs': 34,
#   'lr_init': 0.003995498442143032,
#   'solver': 'adam',
#   'weight_decay': 0.018520408127713762,
# })
#
# is sgd: False | is adam: True
# Config: Configuration(values={
#   'batch_size': 753,
#   'epochs': 65,
#   'lr_init': 0.004509372364462337,
#   'solver': 'adam',
#   'weight_decay': 0.02202813264884113,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3936
# evaluating...
# accuracy: 0.41673333333333334
# Config: Configuration(values={
#   'batch_size': 595,
#   'epochs': 103,
#   'lr_init': 0.0021134202743250414,
#   'solver': 'adam',
#   'weight_decay': 0.0003618920291309289,
# })
#
# is sgd: False | is adam: True
# Config: Configuration(values={
#   'batch_size': 386,
#   'epochs': 120,
#   'lr_init': 0.01374679566339485,
#   'solver': 'adam',
#   'weight_decay': 0.0005795213566496783,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.09846666666666666
# Config: Configuration(values={
#   'batch_size': 673,
#   'epochs': 39,
#   'lr_init': 0.0017686421290636616,
#   'solver': 'adam',
#   'weight_decay': 0.016544451942874176,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4894
# Config: Configuration(values={
#   'batch_size': 920,
#   'epochs': 94,
#   'lr_init': 0.041175408591420534,
#   'solver': 'adam',
#   'weight_decay': 0.0004811094460982545,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.47053333333333336
# evaluating...
# accuracy: 0.0976
# Config: Configuration(values={
#   'batch_size': 451,
#   'epochs': 113,
#   'lr_init': 0.049661114137939284,
#   'solver': 'adam',
#   'weight_decay': 0.0029605774428600163,
# })
#
# is sgd: False | is adam: True
# Config: Configuration(values={
#   'batch_size': 675,
#   'dampening': 0.16991338048882612,
#   'epochs': 94,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.017026254807538856,
#   'momentum': 0.607826296406237,
#   'solver': 'sgd',
#   'weight_decay': 0.06809530508136842,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.09846666666666666
# Config: Configuration(values={
#   'batch_size': 330,
#   'dampening': 0.024431941107417917,
#   'epochs': 93,
#   'learning_rate': 'constant',
#   'lr_init': 0.005695130480281848,
#   'momentum': 0.6725988457635816,
#   'solver': 'sgd',
#   'weight_decay': 0.0022966273565399953,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.41746666666666665
# Config: Configuration(values={
#   'batch_size': 557,
#   'dampening': 0.6564474210690998,
#   'epochs': 111,
#   'learning_rate': 'constant',
#   'lr_init': 0.0956484407922034,
#   'momentum': 0.020444489471071393,
#   'solver': 'sgd',
#   'weight_decay': 0.01884238882532786,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.5047333333333334
# Config: Configuration(values={
#   'batch_size': 338,
#   'epochs': 64,
#   'lr_init': 0.015018765180073968,
#   'solver': 'adam',
#   'weight_decay': 0.02478223675958976,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.09846666666666666
# Config: Configuration(values={
#   'batch_size': 393,
#   'epochs': 68,
#   'lr_init': 0.0010568850641642976,
#   'solver': 'adam',
#   'weight_decay': 0.01385362093494589,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.46373333333333333
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.508
# [INFO][abstract_intensifier.py:590] Added config 658311 and rejected config b1f051 as incumbent because it is not better than the incumbents on 1 instances:
# Config: Configuration(values={
#   'batch_size': 330,
#   'dampening': 0.024431941107417917,
#   'epochs': 93,
#   'learning_rate': 'constant',
#   'lr_init': 0.005695130480281848,
#   'momentum': 0.6725988457635816,
#   'solver': 'sgd',
#   'weight_decay': 0.0022966273565399953,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.49273333333333336
# Config: Configuration(values={
#   'batch_size': 595,
#   'epochs': 103,
#   'lr_init': 0.0021134202743250414,
#   'solver': 'adam',
#   'weight_decay': 0.0003618920291309289,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4894
# Config: Configuration(values={
#   'batch_size': 673,
#   'epochs': 39,
#   'lr_init': 0.0017686421290636616,
#   'solver': 'adam',
#   'weight_decay': 0.016544451942874176,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5047333333333334
# Config: Configuration(values={
#   'batch_size': 971,
#   'epochs': 64,
#   'lr_init': 0.02714684494568181,
#   'solver': 'adam',
#   'weight_decay': 0.001100780059568209,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.47053333333333336
# Config: Configuration(values={
#   'batch_size': 233,
#   'epochs': 68,
#   'lr_init': 0.0018371144479809283,
#   'solver': 'adam',
#   'weight_decay': 0.00010957477139878025,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.09846666666666666
# Config: Configuration(values={
#   'batch_size': 977,
#   'dampening': 0.5786313082662111,
#   'epochs': 32,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.0017181604264581887,
#   'momentum': 0.9519544529960835,
#   'solver': 'sgd',
#   'weight_decay': 0.035223350627705416,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.47333333333333333
# Config: Configuration(values={
#   'batch_size': 753,
#   'epochs': 72,
#   'lr_init': 0.006196114086045528,
#   'solver': 'adam',
#   'weight_decay': 0.00027824193367170487,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3942
# Config: Configuration(values={
#   'batch_size': 231,
#   'dampening': 0.9202340236242686,
#   'epochs': 83,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.0023257320214622387,
#   'momentum': 0.8655450869586976,
#   'solver': 'sgd',
#   'weight_decay': 0.0027233967892805115,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3565333333333333
# Config: Configuration(values={
#   'batch_size': 330,
#   'dampening': 0.024431941107417917,
#   'epochs': 93,
#   'learning_rate': 'constant',
#   'lr_init': 0.005695130480281848,
#   'momentum': 0.6725988457635816,
#   'solver': 'sgd',
#   'weight_decay': 0.0022966273565399953,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.414
# Config: Configuration(values={
#   'batch_size': 709,
#   'dampening': 0.9523170147617567,
#   'epochs': 48,
#   'learning_rate': 'constant',
#   'lr_init': 0.010833236250328237,
#   'momentum': 0.22938461020649248,
#   'solver': 'sgd',
#   'weight_decay': 0.007138879900463324,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.5047333333333334
# Config: Configuration(values={
#   'batch_size': 272,
#   'epochs': 55,
#   'lr_init': 0.013515826983346054,
#   'solver': 'adam',
#   'weight_decay': 0.08820397743075876,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.11993333333333334
# Config: Configuration(values={
#   'batch_size': 517,
#   'dampening': 0.813896555862303,
#   'epochs': 88,
#   'learning_rate': 'constant',
#   'lr_init': 0.005459705437699816,
#   'momentum': 0.5062057927209914,
#   'solver': 'sgd',
#   'weight_decay': 0.00047092428484708175,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3002
# Config: Configuration(values={
#   'batch_size': 233,
#   'epochs': 68,
#   'lr_init': 0.0018371144479809283,
#   'solver': 'adam',
#   'weight_decay': 0.00010957477139878025,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.47333333333333333
# Config: Configuration(values={
#   'batch_size': 405,
#   'epochs': 69,
#   'lr_init': 0.001044671026886073,
#   'solver': 'adam',
#   'weight_decay': 0.0006573533443073463,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5130666666666667
# Config: Configuration(values={
#   'batch_size': 204,
#   'dampening': 0.8732209961275906,
#   'epochs': 112,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.012235223307481224,
#   'momentum': 0.7169259602454279,
#   'solver': 'sgd',
#   'weight_decay': 0.0015742582035347653,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.39866666666666667
# Config: Configuration(values={
#   'batch_size': 191,
#   'epochs': 84,
#   'lr_init': 0.0011972632167892218,
#   'solver': 'adam',
#   'weight_decay': 0.00018931389689679735,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.47913333333333336
# Config: Configuration(values={
#   'batch_size': 375,
#   'epochs': 70,
#   'lr_init': 0.001233943635587122,
#   'solver': 'adam',
#   'weight_decay': 0.01385362093494589,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4744
# Config: Configuration(values={
#   'batch_size': 77,
#   'epochs': 80,
#   'lr_init': 0.0010961692196505943,
#   'solver': 'adam',
#   'weight_decay': 0.0025021499111362007,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.49446666666666667
# Config: Configuration(values={
#   'batch_size': 214,
#   'epochs': 82,
#   'lr_init': 0.0011814559091237178,
#   'solver': 'adam',
#   'weight_decay': 0.008862849991268178,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5072
# Config: Configuration(values={
#   'batch_size': 585,
#   'epochs': 101,
#   'lr_init': 0.0012520304911045538,
#   'solver': 'adam',
#   'weight_decay': 0.00037772327371450473,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4876
# [INFO][smbo.py:319] Finished 50 trials.
# Config: Configuration(values={
#   'batch_size': 393,
#   'dampening': 0.5437659790375291,
#   'epochs': 68,
#   'learning_rate': 'constant',
#   'lr_init': 0.0011923071547098954,
#   'momentum': 0.5714692124456249,
#   'solver': 'sgd',
#   'weight_decay': 0.013391964072807423,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.5089333333333333
# Config: Configuration(values={
#   'batch_size': 367,
#   'dampening': 0.4133612863803927,
#   'epochs': 85,
#   'learning_rate': 'constant',
#   'lr_init': 0.003489341306062742,
#   'momentum': 0.4117943226806635,
#   'solver': 'sgd',
#   'weight_decay': 0.01601224195683716,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3685333333333333
# Config: Configuration(values={
#   'batch_size': 264,
#   'dampening': 0.5491409305748047,
#   'epochs': 90,
#   'learning_rate': 'constant',
#   'lr_init': 0.01082971516786632,
#   'momentum': 0.6995089592102491,
#   'solver': 'sgd',
#   'weight_decay': 0.0017561863934069644,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4336
# Config: Configuration(values={
#   'batch_size': 413,
#   'dampening': 0.4832679248861038,
#   'epochs': 84,
#   'learning_rate': 'constant',
#   'lr_init': 0.001260076760435878,
#   'momentum': 0.47657118811348786,
#   'solver': 'sgd',
#   'weight_decay': 0.00015700468845616505,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.5095333333333333
# Config: Configuration(values={
#   'batch_size': 383,
#   'dampening': 0.49770947146465266,
#   'epochs': 119,
#   'learning_rate': 'constant',
#   'lr_init': 0.0012625486704638859,
#   'momentum': 0.44913610519096175,
#   'solver': 'sgd',
#   'weight_decay': 0.0005299755817243643,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3787333333333333
# Config: Configuration(values={
#   'batch_size': 380,
#   'dampening': 0.5815112603471482,
#   'epochs': 94,
#   'learning_rate': 'constant',
#   'lr_init': 0.001277731273942975,
#   'momentum': 0.6051253074567431,
#   'solver': 'sgd',
#   'weight_decay': 0.0005093682917512504,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3982
# Config: Configuration(values={
#   'batch_size': 385,
#   'dampening': 0.4917071396755667,
#   'epochs': 76,
#   'learning_rate': 'constant',
#   'lr_init': 0.0012698416120316856,
#   'momentum': 0.5402678450748412,
#   'solver': 'sgd',
#   'weight_decay': 0.0001264534147088646,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3947333333333333
# Config: Configuration(values={
#   'batch_size': 405,
#   'epochs': 69,
#   'lr_init': 0.001044671026886073,
#   'solver': 'adam',
#   'weight_decay': 0.0006573533443073463,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5130666666666667
# Config: Configuration(values={
#   'batch_size': 214,
#   'epochs': 82,
#   'lr_init': 0.0011814559091237178,
#   'solver': 'adam',
#   'weight_decay': 0.008862849991268178,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3836
# Config: Configuration(values={
#   'batch_size': 77,
#   'epochs': 80,
#   'lr_init': 0.0010961692196505943,
#   'solver': 'adam',
#   'weight_decay': 0.0025021499111362007,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5089333333333333
# Config: Configuration(values={
#   'batch_size': 264,
#   'dampening': 0.5491409305748047,
#   'epochs': 90,
#   'learning_rate': 'constant',
#   'lr_init': 0.01082971516786632,
#   'momentum': 0.6995089592102491,
#   'solver': 'sgd',
#   'weight_decay': 0.0017561863934069644,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.5072
# Config: Configuration(values={
#   'batch_size': 392,
#   'dampening': 0.024431941107417917,
#   'epochs': 83,
#   'learning_rate': 'constant',
#   'lr_init': 0.001220091216896821,
#   'momentum': 0.6338920266221756,
#   'solver': 'sgd',
#   'weight_decay': 0.0023996444611299704,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.5095333333333333
# [INFO][abstract_intensifier.py:590] Added config bd0f33 and rejected config 658311 as incumbent because it is not better than the incumbents on 1 instances:
# Config: Configuration(values={
#   'batch_size': 327,
#   'dampening': 0.5383020250322471,
#   'epochs': 67,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.0012944532332626487,
#   'momentum': 0.6731916615540458,
#   'solver': 'sgd',
#   'weight_decay': 0.011914551171907728,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.435
# Config: Configuration(values={
#   'batch_size': 380,
#   'dampening': 0.6449636547912981,
#   'epochs': 103,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.0012715178674694947,
#   'momentum': 0.6683748375579386,
#   'solver': 'sgd',
#   'weight_decay': 0.005070314917259989,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3967333333333333
# Config: Configuration(values={
#   'batch_size': 405,
#   'epochs': 69,
#   'lr_init': 0.001044671026886073,
#   'solver': 'adam',
#   'weight_decay': 0.0006573533443073463,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5130666666666667
# [INFO][abstract_intensifier.py:590] Added config 6d0dc7 and rejected config bd0f33 as incumbent because it is not better than the incumbents on 1 instances:
# Config: Configuration(values={
#   'batch_size': 167,
#   'epochs': 68,
#   'lr_init': 0.0010931230357904985,
#   'solver': 'adam',
#   'weight_decay': 0.01291639545778447,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.397
# Config: Configuration(values={
#   'batch_size': 352,
#   'dampening': 0.2511060990142545,
#   'epochs': 114,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.053044101043501574,
#   'momentum': 0.10358160985504934,
#   'solver': 'sgd',
#   'weight_decay': 0.0011102683688613182,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.48346666666666666
# Config: Configuration(values={
#   'batch_size': 335,
#   'epochs': 68,
#   'lr_init': 0.0010283886631786165,
#   'solver': 'adam',
#   'weight_decay': 0.013086605758933967,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4994
# [INFO][smbo.py:327] Configuration budget is exhausted:
# [INFO][smbo.py:328] --- Remaining wallclock time: -105.69794487953186
# [INFO][smbo.py:329] --- Remaining cpu time: inf
# [INFO][smbo.py:330] --- Remaining trials: 9930
# Config: Configuration(values={
#   'batch_size': 322,
#   'epochs': 66,
#   'lr_init': 0.0010906560408651008,
#   'solver': 'adam',
#   'weight_decay': 0.007114231106347787,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5041333333333333
# evaluating...
# accuracy: 0.5099333333333333
# opt execution time: 14888.18820810318 seconds
# incumbent: Configuration(values={
#   'batch_size': 405,
#   'epochs': 69,
#   'lr_init': 0.001044671026886073,
#   'solver': 'adam',
#   'weight_decay': 0.0006573533443073463,
# })
#
# Config: Configuration(values={
#   'batch_size': 520,
#   'dampening': 0.495,
#   'epochs': 75,
#   'learning_rate': 'constant',
#   'lr_init': 0.01,
#   'momentum': 0.495,
#   'solver': 'sgd',
#   'weight_decay': 0.0031622777,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4640666666666667
# Default cost (Hyperband): 0.5359333333333334
# Config: Configuration(values={
#   'batch_size': 405,
#   'epochs': 69,
#   'lr_init': 0.001044671026886073,
#   'solver': 'adam',
#   'weight_decay': 0.0006573533443073463,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.5016
# Incumbent cost (Hyperband): 0.49839999999999995
# appending...
# _acquisition_function <smac.acquisition.function.expected_improvement.EI object at 0x7fd7a7992130>
# _acquisition_maximizer <smac.acquisition.maximizer.local_and_random_search.LocalAndSortedRandomSearch object at 0x7fd7a79921f0>
# _callbacks []
# _config_selector <smac.main.config_selector.ConfigSelector object at 0x7fd7a78fce50>
# _get_optimizer <bound method AbstractFacade._get_optimizer of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# _get_signature_arguments <bound method AbstractFacade._get_signature_arguments of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# _initial_design <smac.initial_design.random_design.RandomInitialDesign object at 0x7fd7a7994400>
# _intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fd7a79942b0>
# _model <smac.model.random_forest.random_forest.RandomForest object at 0x7fd7a79920a0>
# _multi_objective_algorithm None
# _optimizer <smac.main.smbo.SMBO object at 0x7fd7b28070d0>
# _overwrite True
# _random_design <smac.random_design.probability_design.ProbabilityRandomDesign object at 0x7fd7a7992430>
# _runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fd7a78fcdf0>
# _runhistory_encoder <smac.runhistory.encoder.log_scaled_encoder.RunHistoryLogScaledEncoder object at 0x7fd7a78fc8e0>
# _runner <smac.runner.dask_runner.DaskParallelRunner object at 0x7fd78802c730>
# _scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='798fb3c34d8f73b0517fa739989eb5d4', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_1l/798fb3c34d8f73b0517fa739989eb5d4/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# _update_dependencies <bound method AbstractFacade._update_dependencies of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# _validate <bound method AbstractFacade._validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# ask <bound method AbstractFacade.ask of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# get_acquisition_function <function HyperparameterOptimizationFacade.get_acquisition_function at 0x7fd7a777bf70>
# get_acquisition_maximizer <function HyperparameterOptimizationFacade.get_acquisition_maximizer at 0x7fd7a7782040>
# get_config_selector <function AbstractFacade.get_config_selector at 0x7fd7a7715670>
# get_initial_design <function MultiFidelityFacade.get_initial_design at 0x7fd7a7782670>
# get_intensifier <function MultiFidelityFacade.get_intensifier at 0x7fd7a77825e0>
# get_model <function HyperparameterOptimizationFacade.get_model at 0x7fd7a777bee0>
# get_multi_objective_algorithm <function HyperparameterOptimizationFacade.get_multi_objective_algorithm at 0x7fd7a7782280>
# get_random_design <function HyperparameterOptimizationFacade.get_random_design at 0x7fd7a77821f0>
# get_runhistory_encoder <function HyperparameterOptimizationFacade.get_runhistory_encoder at 0x7fd7a7782310>
# intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fd7a79942b0>
# meta {'facade': {'name': 'MultiFidelityFacade'}, 'runner': {'name': 'DaskParallelRunner'}, 'model': {'name': 'RandomForest', 'types': [0, 0, 0, 2, 0, 4, 0, 0], 'bounds': [(0, 1.0), (0, 1.0), (0, 1.0), (2, nan), (-1.0, 1.0), (4, nan), (-1.0, 1.0), (-1.0, 1.0)], 'pca_components': 7, 'n_trees': 10, 'n_points_per_tree': -1, 'ratio_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 1048576, 'eps_purity': 1e-08, 'max_nodes': 1048576, 'bootstrapping': True}, 'acquisition_maximizer': {'name': 'LocalAndSortedRandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 10000, 'seed': 0, 'random_search': {'name': 'RandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0}, 'local_search': {'name': 'LocalSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0, 'max_steps': None, 'n_steps_plateau_walk': 10, 'vectorization_min_obtain': 2, 'vectorization_max_obtain': 64}}, 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'intensifier': {'name': 'Hyperband', 'max_incumbents': 10, 'seed': 0, 'eta': 3, 'instance_seed_order': 'shuffle_once', 'incumbent_selection': 'highest_budget'}, 'initial_design': {'name': 'RandomInitialDesign', 'n_configs': 5, 'n_configs_per_hyperparameter': 10, 'additional_configs': [], 'seed': 0}, 'random_design': {'name': 'ProbabilityRandomDesign', 'seed': 0, 'probability': 0.2}, 'runhistory_encoder': {'name': 'RunHistoryLogScaledEncoder', 'considered_states': [<StatusType.SUCCESS: 1>, <StatusType.CRASHED: 2>, <StatusType.MEMORYOUT: 4>], 'lower_budget_states': [], 'scale_percentage': 5, 'seed': 0}, 'multi_objective_algorithm': None, 'config_selector': {'name': 'ConfigSelector', 'retrain_after': 8, 'retries': 16, 'min_trials': 1}, 'version': '2.0.2'}
# optimize <bound method AbstractFacade.optimize of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# optimizer <smac.main.smbo.SMBO object at 0x7fd7b28070d0>
# runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fd7a78fcdf0>
# scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='798fb3c34d8f73b0517fa739989eb5d4', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_1l/798fb3c34d8f73b0517fa739989eb5d4/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# tell <bound method AbstractFacade.tell of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# validate <bound method AbstractFacade.validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>>
# attempting to plot
# facades: [<smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd7a7994250>]
#
# facades[0]: Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='798fb3c34d8f73b0517fa739989eb5d4', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_1l/798fb3c34d8f73b0517fa739989eb5d4/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# <class 'float'> 0.5262
# <class 'float'> 0.492
# <class 'float'> 0.4904666666666667
# <class 'float'> 0.48693333333333333
# Timer unit: 1e-09 s
#
# Total time: 15028.1 s
# File: /var/folders/w0/pq4q2kj50fvdt6t_4y4gqfvw0000gn/T/ipykernel_43860/1149617428.py
# Function: main at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def main():
#      5
#      6
#      7         1    1634000.0    2e+06      0.0      CNN32 = CNN32Wrapper()
#      8
#      9         1          0.0      0.0      0.0      facades: list[AbstractFacade] = []
#     10         2       7000.0   3500.0      0.0      for intensifier_object in [Hyperband]:
#     11                                                   # Define our environment variables
#     12
#     13         2      24000.0  12000.0      0.0          scenario = Scenario(
#     14         1    5712000.0    6e+06      0.0              CNN32.configspace,
#     15         1       1000.0   1000.0      0.0              walltime_limit=14400,  # After 3600 seconds, we stop the hyperparameter optimization
#     16         1      53000.0  53000.0      0.0              output_directory=Path("smac_hyperband_output_budget_4hr_CNN_1l"),
#     17         1       1000.0   1000.0      0.0              n_trials=10000,  # Evaluate max 500 different trials
#     18         1          0.0      0.0      0.0              min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
#     19                                                       # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
#     20         1          0.0      0.0      0.0              max_budget=1000,  # only for CNN32_5layers, Resnet18
#     21         1          0.0      0.0      0.0              n_workers=2,
#     22                                                   )
#     23
#     24
#     25
#     26                                                   # We want to run five random configurations before starting the optimization.
#     27         1     479000.0 479000.0      0.0          initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
#     28
#     29                                                   # Create our intensifier
#     30         1     168000.0 168000.0      0.0          intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
#     31
#     32                                                   # Create our SMAC object and pass the scenario and the train method
#     33         2  933493000.0    5e+08      0.0          smac = MFFacade(
#     34         1       1000.0   1000.0      0.0              scenario,
#     35         1       1000.0   1000.0      0.0              CNN32.fit,
#     36         1          0.0      0.0      0.0              initial_design=initial_design,
#     37         1          0.0      0.0      0.0              intensifier=intensifier,
#     38         1          0.0      0.0      0.0              overwrite=True,
#     39                                                   )
#     40                                                   # print("I fitted!!!!!!!!!!!!!!:", smac)
#     41
#     42                                                   # Let's optimize
#     43         1      46000.0  46000.0      0.0          print("optimizing...")
#     44         1      16000.0  16000.0      0.0          print(type(smac), "|", smac)
#     45         1       1000.0   1000.0      0.0          opt_start_time = time.time()
#     46         1        1e+13    1e+13     99.1          incumbent = smac.optimize()
#     47         1       2000.0   2000.0      0.0          opt_end_time = time.time()
#     48         1     115000.0 115000.0      0.0          print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
#     49         1      23000.0  23000.0      0.0          print("incumbent:", incumbent)
#     50                                                   # break
#     51                                                   # Get cost of default configuration
#     52         1        1e+11    1e+11      0.7          default_cost = smac.validate(CNN32.configspace.get_default_configuration())
#     53         1      96000.0  96000.0      0.0          print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")
#     54
#     55                                                   # Let's calculate the cost of the incumbent
#     56         1        3e+10    3e+10      0.2          incumbent_cost = smac.validate(incumbent)
#     57         1      94000.0  94000.0      0.0          print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
#     58         1       5000.0   5000.0      0.0          print("appending...")
#     59         1       1000.0   1000.0      0.0          facades.append(smac)
#     60        64     382000.0   5968.8      0.0          for attr in dir(smac):
#     61        63      28000.0    444.4      0.0              if not attr.startswith('__'):
#     62        37    1147000.0  31000.0      0.0                  print(attr, getattr(smac, attr))
#     63         1       4000.0   4000.0      0.0      print("attempting to plot")
#     64                                               # Let's plot it
#     65         1       9000.0   9000.0      0.0      print("facades:", facades)
#     66                                               # BO_file = "CNN32_5l_BO_results_2h.txt"
#     67         1  347239000.0    3e+08      0.0      plot_trajectory(facades)

# %%
class CNN32Wrapper(BaseEstimator):
    def __init__(self, criterion = nn.CrossEntropyLoss()):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = cnn32_2l.to(self.device)
        self.criterion = criterion
        self.lr = None
        self.batch_size = None
        self.epochs = None
        self.optimizer = None

    @property
    def configspace(self)-> ConfigurationSpace:
        cs = ConfigurationSpace()
        lr_init = Float("lr_init", (0.00001, 0.1), log=True)
        learning_rate = Categorical("learning_rate", ["constant", "invscaling", "adaptive"], default="constant")
        solver = Categorical("solver", ["sgd", "adam"])
        batch_size = Integer("batch_size", (16, 1024))
        epochs = Integer("epochs", (30, 160))
        cs.add_hyperparameters([lr_init, learning_rate, solver, batch_size, epochs])

        use_lr = EqualsCondition(child=learning_rate, parent=solver, value="sgd")
        cs.add_conditions([use_lr])

        weight_decay = Float("weight_decay", (0.0001, 0.1), log=True)
        momentum = Float("momentum", (0, 0.99))
        dampening = Float("dampening", (0, 0.99))
        cs.add_hyperparameters([weight_decay, momentum, dampening])

        weight_decay_condition = InCondition(child=weight_decay, parent=solver, values=["sgd", "adam"])
        momentum_condition = InCondition(child=momentum, parent=solver, values=["sgd"])
        dampening_condition = InCondition(child=dampening, parent=solver, values=["sgd"])
        cs.add_conditions([use_lr, weight_decay_condition, momentum_condition, dampening_condition])

        return cs
    
    def fit(self, config: Configuration, seed: int = 0, budget: int = 250) -> float: 
        self.trial_start_time = time.perf_counter()

        print("Config:", config)
        # print(time.time())
        epoch_start_timer = time.perf_counter()
        # print("okay here?")
        max_epochs = [0]
        # print("what abt here?")

        X = torch.tensor(train_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        y = torch.tensor(train_y, dtype=torch.long)
        valid_x_inFit = torch.tensor(valid_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        valid_y_inFit = torch.tensor(valid_y, dtype=torch.long)


        # print("so far so good")
        # print("Model:", self.model)
        model = self.model
        # print("break1")
        # print("Criterion:", self.criterion)
        criterion = self.criterion

        self.lr = config.get('lr_init')
        # print("lr:", self.lr)
        self.epochs = config.get('epochs')
        # print("epochs:", self.epochs)
        self.batch_size = config.get('batch_size')
        # print("batch_size:", self.batch_size)
        # print("solver type:", type(self.sovler))
        solver_name = config.get('solver', 'sgd')
        # print("solver_name:", solver_name, type(solver_name))
        momentum = config.get('momentum', 0.9)
        weight_decay = config.get('weight_decay', 0.9)
        dampening = config.get('dampening', 0.9)
        print("is sgd:", solver_name=='sgd', "| is adam:", solver_name=='adam')
        # print(self.model.parameters())
        if solver_name == 'sgd':
            self.optimizer = optim.SGD(self.model.parameters(), lr=self.lr, momentum=momentum, weight_decay=weight_decay, dampening=dampening)

        elif solver_name == 'adam':
            self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr, weight_decay=weight_decay)

        else:
            raise ValueError(f"Unknown optimizer: {solver_name}")
        prev_loss = float("inf")
        flag = 0

        for epoch in range(self.epochs):
            model.train()
            for i in range(0, len(X), self.batch_size):
                # print(type(X), type(y))
                inputs = X[i : i + self.batch_size].to(self.device)
                labels = y[i : i + self.batch_size].to(self.device)
                self.optimizer.zero_grad()
                if inputs.shape[0] <= 2:
                    continue
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()

            model.eval()
            cur_loss = 0
            with torch.no_grad():
                for i in range(0, len(valid_x_inFit), self.batch_size):
                    # get the inputs
                    inputs = valid_x_inFit[i : i + self.batch_size].to(self.device)
                    labels = valid_y_inFit[i : i + self.batch_size].to(self.device)
                    if inputs.shape[0] == 1:
                        inputs = torch.cat((inputs, inputs, inputs), dim = 0)
                        labels = torch.cat((labels, labels, labels), dim = 0)

                    # forward
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    cur_loss += loss
            
            if cur_loss < prev_loss:
                prev_loss = cur_loss
                flag = 0
            else:
                flag += 1
                if flag >= 3:
                    max_epochs.append(epoch)
                    break

        # print(np.max(max_epochs))
        print("evaluating...")
        model.eval()
        with torch.no_grad():
            outputs = model(valid_x_inFit.to(self.device))
            _, predicted = torch.max(outputs.data, 1)
            predictions = predicted.cpu().numpy()
        acc = accuracy_score(valid_y, predictions)
        print("accuracy:", acc)

        self.trial_end_time = time.perf_counter()
        valid_probs = self.predict_proba(valid_x_inFit)
        valid_kappa = cohen_kappa_score(valid_y, predictions)
        valid_ece = get_ece(valid_probs, predictions, valid_y)
        with open('smac_results_2h.txt', "a") as f:
            f.write(f"Valid Accuracy: {acc}, Valid Kappa: {valid_kappa}, Valid ECE: {valid_ece}, Time: {self.trial_end_time - self.trial_start_time}\n")
            
        return 1-acc
    
    def predict_proba(self, X):
        # X = X.reshape(-1, 3, 32, 32)
        model = self.model
        model.eval()
        test_probs = []
        with torch.no_grad():
            outputs = model(X.to(self.device))
            test_prob = nn.Softmax(dim=1)(outputs)
            test_probs = test_prob.cpu().numpy()
            return test_probs
        
def plot_trajectory(facades: list[AbstractFacade], BO_file = None) -> None:
    """Plots the trajectory (incumbents) of the optimization process."""
    plt.figure()
    plt.title("Trajectory")
    plt.xlabel("Wallclock time [s]")
    # print(len(facades))
    plt.ylabel("Accuracy")
    print("\nfacades[0]:", facades[0].scenario)
    # print("\nfacades[1]:", facades[1].scenario)
    # plt.ylim(0, 0.4)

    for facade in facades:
        X, Y = [], []
        for item in facade.intensifier.trajectory:
            # Single-objective optimization
            assert len(item.config_ids) == 1
            assert len(item.costs) == 1
            # print(1 - round(item.costs[0], 3))
            y = item.costs[0]
            x = item.walltime
            print(type(item.costs[0]), item.costs[0])
            X.append(x)
            Y.append(1-y)

        plt.plot(X, Y, label=facade.intensifier.__class__.__name__)
        plt.scatter(X, Y, marker="o")

    if BO_file:
        with open(BO_file, "r") as f:
            data = f.readlines()
        bo_accuracy, bo_kappa, bo_ece, bo_time = [], [], [], []

        # Parse the data
        for line in data:
            # Using regular expression to find all the floating point numbers in each line
            if "Time: " in line:
                numbers = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                if numbers:
                    bo_accuracy.append(float(numbers[0]))
                    bo_kappa.append(float(numbers[1]))
                    bo_ece.append(float(numbers[2]))
                    bo_time.append(float(numbers[3]))

        max_bo_accs = np.maximum.accumulate(bo_accuracy)
        bo_cum_time = np.cumsum(bo_time)
        plt.plot(bo_cum_time, max_bo_accs, label='Max BO Accuracies', marker='x')
    

    plt.legend()
    plt.show()

# %%
from line_profiler import LineProfiler
from pathlib import Path
# @timeout(21600)
def main():

    
    CNN32 = CNN32Wrapper()

    facades: list[AbstractFacade] = []
    for intensifier_object in [Hyperband]:
        # Define our environment variables
        
        scenario = Scenario(
            CNN32.configspace,
            walltime_limit=21600,  # After 3600 seconds, we stop the hyperparameter optimization
            output_directory=Path("smac_hyperband_output_budget_6hr_CNN_2l"),
            n_trials=10000,  # Evaluate max 500 different trials
            min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
            # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
            max_budget=1000,  # only for CNN32_5layers, Resnet18
            n_workers=2,
        )


        
        # We want to run five random configurations before starting the optimization.
        initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
        
        # Create our intensifier
        intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
        
        # Create our SMAC object and pass the scenario and the train method
        smac = MFFacade(
            scenario,
            CNN32.fit,
            initial_design=initial_design,
            intensifier=intensifier,
            overwrite=True,
        )
        # print("I fitted!!!!!!!!!!!!!!:", smac)

        # Let's optimize
        print("optimizing...")
        print(type(smac), "|", smac)
        opt_start_time = time.time()
        incumbent = smac.optimize()
        opt_end_time = time.time()
        print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
        print("incumbent:", incumbent)
        # break
        # Get cost of default configuration
        default_cost = smac.validate(CNN32.configspace.get_default_configuration())
        print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")

        # Let's calculate the cost of the incumbent
        incumbent_cost = smac.validate(incumbent)
        print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
        print("appending...")
        facades.append(smac)
        for attr in dir(smac):
            if not attr.startswith('__'):
                print(attr, getattr(smac, attr))
    print("attempting to plot")
    # Let's plot it
    print("facades:", facades)
    # BO_file = "CNN32_5l_BO_results_2h.txt"
    plot_trajectory(facades)

if __name__ == "__main__":
    with open('smac_results_2h.txt', "w") as f:
        pass
    profiler = LineProfiler()
    profiler.add_function(main)
    profiler.enable()

    main()

    profiler.disable()
    profiler.print_stats()
# Out:
# [INFO][abstract_initial_design.py:82] Using `n_configs` and ignoring `n_configs_per_hyperparameter`.
# [INFO][abstract_initial_design.py:147] Using 5 initial design configurations and 0 additional configurations.
# optimizing...
# <class 'smac.facade.multi_fidelity_facade.MultiFidelityFacade'> | <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>
# [INFO][successive_halving.py:164] Successive Halving uses budget type BUDGETS with eta 3, min budget 100, and max budget 1000.
# [INFO][successive_halving.py:323] Number of configs in stage:
# [INFO][successive_halving.py:325] --- Bracket 0: [9, 3, 1]
# [INFO][successive_halving.py:325] --- Bracket 1: [5, 1]
# [INFO][successive_halving.py:325] --- Bracket 2: [3]
# [INFO][successive_halving.py:327] Budgets in stage:
# [INFO][successive_halving.py:329] --- Bracket 0: [111.1111111111111, 333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 1: [333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 2: [1000.0]
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 569,
#   'dampening': 0.9688321588104364,
#   'epochs': 88,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.03832216850492789,
#   'momentum': 0.2619100559835807,
#   'solver': 'sgd',
#   'weight_decay': 0.007126995609048582,
# })
#
# is sgd: True | is adam: False
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 737,
#   'dampening': 0.7911669785745563,
#   'epochs': 69,
#   'learning_rate': 'constant',
#   'lr_init': 0.011423254155608374,
#   'momentum': 0.7664913525398744,
#   'solver': 'sgd',
#   'weight_decay': 0.006859416411328701,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3968
# Config: Configuration(values={
#   'batch_size': 624,
#   'epochs': 111,
#   'lr_init': 0.013680095279726922,
#   'solver': 'adam',
#   'weight_decay': 0.0070925432147358365,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.09846666666666666
# Config: Configuration(values={
#   'batch_size': 565,
#   'epochs': 117,
#   'lr_init': 0.07098936257405905,
#   'solver': 'adam',
#   'weight_decay': 0.06780227021579836,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.0976
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3132666666666667
# Config: Configuration(values={
#   'batch_size': 378,
#   'dampening': 0.660099048291211,
#   'epochs': 69,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.024846338168982397,
#   'momentum': 0.2082787354631025,
#   'solver': 'sgd',
#   'weight_decay': 0.00024365700014641997,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.48966666666666664
# Config: Configuration(values={
#   'batch_size': 334,
#   'dampening': 0.9784900996786339,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.01381635682257479,
#   'momentum': 0.20678798853388633,
#   'solver': 'sgd',
#   'weight_decay': 0.000304739361773639,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4638
# Config: Configuration(values={
#   'batch_size': 674,
#   'dampening': 0.15737988780906453,
#   'epochs': 53,
#   'learning_rate': 'constant',
#   'lr_init': 0.008562913278818234,
#   'momentum': 0.6497662935706207,
#   'solver': 'sgd',
#   'weight_decay': 0.0002597459914786609,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.1772
# Config: Configuration(values={
#   'batch_size': 214,
#   'dampening': 0.8295654584238159,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.043851702560851274,
#   'momentum': 0.9666948703632617,
#   'solver': 'sgd',
#   'weight_decay': 0.002546558192892438,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.49566666666666664
# Config: Configuration(values={
#   'batch_size': 423,
#   'epochs': 49,
#   'lr_init': 0.004336485563242767,
#   'solver': 'adam',
#   'weight_decay': 0.016877633409699246,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.45
# Config: Configuration(values={
#   'batch_size': 410,
#   'epochs': 106,
#   'lr_init': 0.0030533532017211072,
#   'solver': 'adam',
#   'weight_decay': 0.02455299801910569,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4428
# Config: Configuration(values={
#   'batch_size': 408,
#   'epochs': 79,
#   'lr_init': 0.0044410165269036985,
#   'solver': 'adam',
#   'weight_decay': 0.0111234888889169,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3696
# Config: Configuration(values={
#   'batch_size': 412,
#   'epochs': 69,
#   'lr_init': 0.0012997911055993535,
#   'solver': 'adam',
#   'weight_decay': 0.010162371659715917,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.48313333333333336
# Config: Configuration(values={
#   'batch_size': 108,
#   'epochs': 41,
#   'lr_init': 0.0031282971911658986,
#   'solver': 'adam',
#   'weight_decay': 0.012889975847464511,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4368666666666667
# Config: Configuration(values={
#   'batch_size': 214,
#   'dampening': 0.8295654584238159,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.043851702560851274,
#   'momentum': 0.9666948703632617,
#   'solver': 'sgd',
#   'weight_decay': 0.002546558192892438,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.49566666666666664
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.4311333333333333
# Config: Configuration(values={
#   'batch_size': 378,
#   'dampening': 0.660099048291211,
#   'epochs': 69,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.024846338168982397,
#   'momentum': 0.2082787354631025,
#   'solver': 'sgd',
#   'weight_decay': 0.00024365700014641997,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.48966666666666664
# Config: Configuration(values={
#   'batch_size': 405,
#   'dampening': 0.20289432211640715,
#   'epochs': 51,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.003340080181980782,
#   'momentum': 0.6497662935706207,
#   'solver': 'sgd',
#   'weight_decay': 0.0002597459914786609,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.4638
# [INFO][smbo.py:327] Configuration budget is exhausted:
# [INFO][smbo.py:328] --- Remaining wallclock time: -8.281857013702393
# [INFO][smbo.py:329] --- Remaining cpu time: inf
# [INFO][smbo.py:330] --- Remaining trials: 9981
# Config: Configuration(values={
#   'batch_size': 424,
#   'epochs': 73,
#   'lr_init': 0.0021886233870665557,
#   'solver': 'adam',
#   'weight_decay': 0.0002879950786865591,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.40653333333333336
# [INFO][abstract_intensifier.py:515] Added config 35b110 as new incumbent because there are no incumbents yet.
# evaluating...
# accuracy: 0.48033333333333333
# [INFO][abstract_intensifier.py:590] Added config a3d41b and rejected config 35b110 as incumbent because it is not better than the incumbents on 1 instances:
# opt execution time: 15084.424998998642 seconds
# incumbent: Configuration(values={
#   'batch_size': 424,
#   'epochs': 73,
#   'lr_init': 0.0021886233870665557,
#   'solver': 'adam',
#   'weight_decay': 0.0002879950786865591,
# })
#
# Config: Configuration(values={
#   'batch_size': 520,
#   'dampening': 0.495,
#   'epochs': 75,
#   'learning_rate': 'constant',
#   'lr_init': 0.01,
#   'momentum': 0.495,
#   'solver': 'sgd',
#   'weight_decay': 0.0031622777,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.43966666666666665
# Default cost (Hyperband): 0.5603333333333333
# Config: Configuration(values={
#   'batch_size': 424,
#   'epochs': 73,
#   'lr_init': 0.0021886233870665557,
#   'solver': 'adam',
#   'weight_decay': 0.0002879950786865591,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.463
# Incumbent cost (Hyperband): 0.5369999999999999
# appending...
# _acquisition_function <smac.acquisition.function.expected_improvement.EI object at 0x7fd7a7992280>
# _acquisition_maximizer <smac.acquisition.maximizer.local_and_random_search.LocalAndSortedRandomSearch object at 0x7fd7b17f88e0>
# _callbacks []
# _config_selector <smac.main.config_selector.ConfigSelector object at 0x7fd7b17f8a90>
# _get_optimizer <bound method AbstractFacade._get_optimizer of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# _get_signature_arguments <bound method AbstractFacade._get_signature_arguments of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# _initial_design <smac.initial_design.random_design.RandomInitialDesign object at 0x7fd7a796b160>
# _intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fd7a79942e0>
# _model <smac.model.random_forest.random_forest.RandomForest object at 0x7fd7a79921c0>
# _multi_objective_algorithm None
# _optimizer <smac.main.smbo.SMBO object at 0x7fd7a79cb490>
# _overwrite True
# _random_design <smac.random_design.probability_design.ProbabilityRandomDesign object at 0x7fd7b17f8640>
# _runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fd7b17f8220>
# _runhistory_encoder <smac.runhistory.encoder.log_scaled_encoder.RunHistoryLogScaledEncoder object at 0x7fd7b17f8910>
# _runner <smac.runner.dask_runner.DaskParallelRunner object at 0x7fd7a796b100>
# _scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='07640c0596c9a6dd06fbc4c01829df39', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_2l/07640c0596c9a6dd06fbc4c01829df39/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# _update_dependencies <bound method AbstractFacade._update_dependencies of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# _validate <bound method AbstractFacade._validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# ask <bound method AbstractFacade.ask of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# get_acquisition_function <function HyperparameterOptimizationFacade.get_acquisition_function at 0x7fd7a777bf70>
# get_acquisition_maximizer <function HyperparameterOptimizationFacade.get_acquisition_maximizer at 0x7fd7a7782040>
# get_config_selector <function AbstractFacade.get_config_selector at 0x7fd7a7715670>
# get_initial_design <function MultiFidelityFacade.get_initial_design at 0x7fd7a7782670>
# get_intensifier <function MultiFidelityFacade.get_intensifier at 0x7fd7a77825e0>
# get_model <function HyperparameterOptimizationFacade.get_model at 0x7fd7a777bee0>
# get_multi_objective_algorithm <function HyperparameterOptimizationFacade.get_multi_objective_algorithm at 0x7fd7a7782280>
# get_random_design <function HyperparameterOptimizationFacade.get_random_design at 0x7fd7a77821f0>
# get_runhistory_encoder <function HyperparameterOptimizationFacade.get_runhistory_encoder at 0x7fd7a7782310>
# intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fd7a79942e0>
# meta {'facade': {'name': 'MultiFidelityFacade'}, 'runner': {'name': 'DaskParallelRunner'}, 'model': {'name': 'RandomForest', 'types': [0, 0, 0, 2, 0, 4, 0, 0], 'bounds': [(0, 1.0), (0, 1.0), (0, 1.0), (2, nan), (-1.0, 1.0), (4, nan), (-1.0, 1.0), (-1.0, 1.0)], 'pca_components': 7, 'n_trees': 10, 'n_points_per_tree': -1, 'ratio_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 1048576, 'eps_purity': 1e-08, 'max_nodes': 1048576, 'bootstrapping': True}, 'acquisition_maximizer': {'name': 'LocalAndSortedRandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 10000, 'seed': 0, 'random_search': {'name': 'RandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0}, 'local_search': {'name': 'LocalSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0, 'max_steps': None, 'n_steps_plateau_walk': 10, 'vectorization_min_obtain': 2, 'vectorization_max_obtain': 64}}, 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'intensifier': {'name': 'Hyperband', 'max_incumbents': 10, 'seed': 0, 'eta': 3, 'instance_seed_order': 'shuffle_once', 'incumbent_selection': 'highest_budget'}, 'initial_design': {'name': 'RandomInitialDesign', 'n_configs': 5, 'n_configs_per_hyperparameter': 10, 'additional_configs': [], 'seed': 0}, 'random_design': {'name': 'ProbabilityRandomDesign', 'seed': 0, 'probability': 0.2}, 'runhistory_encoder': {'name': 'RunHistoryLogScaledEncoder', 'considered_states': [<StatusType.SUCCESS: 1>, <StatusType.CRASHED: 2>, <StatusType.MEMORYOUT: 4>], 'lower_budget_states': [], 'scale_percentage': 5, 'seed': 0}, 'multi_objective_algorithm': None, 'config_selector': {'name': 'ConfigSelector', 'retrain_after': 8, 'retries': 16, 'min_trials': 1}, 'version': '2.0.2'}
# optimize <bound method AbstractFacade.optimize of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# optimizer <smac.main.smbo.SMBO object at 0x7fd7a79cb490>
# runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fd7b17f8220>
# scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='07640c0596c9a6dd06fbc4c01829df39', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_2l/07640c0596c9a6dd06fbc4c01829df39/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# tell <bound method AbstractFacade.tell of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# validate <bound method AbstractFacade.validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>>
# attempting to plot
# facades: [<smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fd790a6a9a0>]
#
# facades[0]: Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='07640c0596c9a6dd06fbc4c01829df39', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_2l/07640c0596c9a6dd06fbc4c01829df39/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# <class 'float'> 0.5934666666666666
# <class 'float'> 0.5196666666666667
# Timer unit: 1e-09 s
#
# Total time: 15909.7 s
# File: /var/folders/w0/pq4q2kj50fvdt6t_4y4gqfvw0000gn/T/ipykernel_43860/306258932.py
# Function: main at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def main():
#      5
#      6
#      7         1    2072000.0    2e+06      0.0      CNN32 = CNN32Wrapper()
#      8
#      9         1          0.0      0.0      0.0      facades: list[AbstractFacade] = []
#     10         2       2000.0   1000.0      0.0      for intensifier_object in [Hyperband]:
#     11                                                   # Define our environment variables
#     12
#     13         2      30000.0  15000.0      0.0          scenario = Scenario(
#     14         1    1506000.0    2e+06      0.0              CNN32.configspace,
#     15         1          0.0      0.0      0.0              walltime_limit=14400,  # After 3600 seconds, we stop the hyperparameter optimization
#     16         1      31000.0  31000.0      0.0              output_directory=Path("smac_hyperband_output_budget_4hr_CNN_2l"),
#     17         1          0.0      0.0      0.0              n_trials=10000,  # Evaluate max 500 different trials
#     18         1          0.0      0.0      0.0              min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
#     19                                                       # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
#     20         1       1000.0   1000.0      0.0              max_budget=1000,  # only for CNN32_5layers, Resnet18
#     21         1          0.0      0.0      0.0              n_workers=2,
#     22                                                   )
#     23
#     24
#     25
#     26                                                   # We want to run five random configurations before starting the optimization.
#     27         1    1443000.0    1e+06      0.0          initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
#     28
#     29                                                   # Create our intensifier
#     30         1     233000.0 233000.0      0.0          intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
#     31
#     32                                                   # Create our SMAC object and pass the scenario and the train method
#     33         2 1306200000.0    7e+08      0.0          smac = MFFacade(
#     34         1          0.0      0.0      0.0              scenario,
#     35         1       1000.0   1000.0      0.0              CNN32.fit,
#     36         1          0.0      0.0      0.0              initial_design=initial_design,
#     37         1          0.0      0.0      0.0              intensifier=intensifier,
#     38         1          0.0      0.0      0.0              overwrite=True,
#     39                                                   )
#     40                                                   # print("I fitted!!!!!!!!!!!!!!:", smac)
#     41
#     42                                                   # Let's optimize
#     43         1      58000.0  58000.0      0.0          print("optimizing...")
#     44         1      21000.0  21000.0      0.0          print(type(smac), "|", smac)
#     45         1       1000.0   1000.0      0.0          opt_start_time = time.time()
#     46         1        2e+13    2e+13     94.8          incumbent = smac.optimize()
#     47         1       5000.0   5000.0      0.0          opt_end_time = time.time()
#     48         1      66000.0  66000.0      0.0          print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
#     49         1      22000.0  22000.0      0.0          print("incumbent:", incumbent)
#     50                                                   # break
#     51                                                   # Get cost of default configuration
#     52         1        6e+11    6e+11      3.8          default_cost = smac.validate(CNN32.configspace.get_default_configuration())
#     53         1     112000.0 112000.0      0.0          print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")
#     54
#     55                                                   # Let's calculate the cost of the incumbent
#     56         1        2e+11    2e+11      1.4          incumbent_cost = smac.validate(incumbent)
#     57         1     112000.0 112000.0      0.0          print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
#     58         1      11000.0  11000.0      0.0          print("appending...")
#     59         1       8000.0   8000.0      0.0          facades.append(smac)
#     60        64     399000.0   6234.4      0.0          for attr in dir(smac):
#     61        63      22000.0    349.2      0.0              if not attr.startswith('__'):
#     62        37    1376000.0  37189.2      0.0                  print(attr, getattr(smac, attr))
#     63         1       5000.0   5000.0      0.0      print("attempting to plot")
#     64                                               # Let's plot it
#     65         1      11000.0  11000.0      0.0      print("facades:", facades)
#     66                                               # BO_file = "CNN32_5l_BO_results_2h.txt"
#     67         1  261443000.0    3e+08      0.0      plot_trajectory(facades)

# %%
class CNN32Wrapper(BaseEstimator):
    def __init__(self, criterion = nn.CrossEntropyLoss()):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = cnn32_5l.to(self.device)
        self.criterion = criterion
        self.lr = None
        self.batch_size = None
        self.epochs = None
        self.optimizer = None

    @property
    def configspace(self)-> ConfigurationSpace:
        cs = ConfigurationSpace()
        lr_init = Float("lr_init", (0.00001, 0.1), log=True)
        learning_rate = Categorical("learning_rate", ["constant", "invscaling", "adaptive"], default="constant")
        solver = Categorical("solver", ["sgd", "adam"])
        batch_size = Integer("batch_size", (16, 1024))
        epochs = Integer("epochs", (30, 160))
        cs.add_hyperparameters([lr_init, learning_rate, solver, batch_size, epochs])

        use_lr = EqualsCondition(child=learning_rate, parent=solver, value="sgd")
        cs.add_conditions([use_lr])

        weight_decay = Float("weight_decay", (0.0001, 0.1), log=True)
        momentum = Float("momentum", (0, 0.99))
        dampening = Float("dampening", (0, 0.99))
        cs.add_hyperparameters([weight_decay, momentum, dampening])

        weight_decay_condition = InCondition(child=weight_decay, parent=solver, values=["sgd", "adam"])
        momentum_condition = InCondition(child=momentum, parent=solver, values=["sgd"])
        dampening_condition = InCondition(child=dampening, parent=solver, values=["sgd"])
        cs.add_conditions([use_lr, weight_decay_condition, momentum_condition, dampening_condition])

        return cs
    
    def fit(self, config: Configuration, seed: int = 0, budget: int = 250) -> float: 
        self.trial_start_time = time.perf_counter()

        print("Config:", config)
        # print(time.time())
        epoch_start_timer = time.perf_counter()
        # print("okay here?")
        max_epochs = [0]
        # print("what abt here?")

        X = torch.tensor(train_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        y = torch.tensor(train_y, dtype=torch.long)
        valid_x_inFit = torch.tensor(valid_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        valid_y_inFit = torch.tensor(valid_y, dtype=torch.long)


        # ### only for resnet:
        # X = X.repeat(1, 3, 1, 1)
        # valid_x_inFit = valid_x_inFit.repeat(1, 3, 1, 1)


        # print("so far so good")
        # print("Model:", self.model)
        model = self.model
        # print("break1")
        # print("Criterion:", self.criterion)
        criterion = self.criterion

        self.lr = config.get('lr_init')
        # print("lr:", self.lr)
        self.epochs = config.get('epochs')
        # print("epochs:", self.epochs)
        self.batch_size = config.get('batch_size')
        # print("batch_size:", self.batch_size)
        # print("solver type:", type(self.sovler))
        solver_name = config.get('solver', 'sgd')
        # print("solver_name:", solver_name, type(solver_name))
        momentum = config.get('momentum', 0.9)
        weight_decay = config.get('weight_decay', 0.9)
        dampening = config.get('dampening', 0.9)
        print("is sgd:", solver_name=='sgd', "| is adam:", solver_name=='adam')
        # print(self.model.parameters())
        if solver_name == 'sgd':
            # optimizer_args = {
            #     'lr': self.lr,
            #     'momentum': config.get('momentum', 0),
            #     'weight_decay': config.get('weight_decay', 0),
            #     'dampening': config.get('dampening', 0)
            # }
            self.optimizer = optim.SGD(self.model.parameters(), lr=self.lr, momentum=momentum, weight_decay=weight_decay, dampening=dampening)

        elif solver_name == 'adam':
            # optimizer_args = {
            #     'lr': self.lr,
            #     'weight_decay': config.get('weight_decay', 0) 
            # }
            self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr, weight_decay=weight_decay)

        else:
            raise ValueError(f"Unknown optimizer: {solver_name}")
        # print("solver type:", type(self.optimizer))
        # print("solver:", self.optimizer)
        prev_loss = float("inf")
        flag = 0

        for epoch in range(self.epochs):
            model.train()
            for i in range(0, len(X), self.batch_size):
                # print(type(X), type(y))
                inputs = X[i : i + self.batch_size].to(self.device)
                labels = y[i : i + self.batch_size].to(self.device)
                self.optimizer.zero_grad()
                if inputs.shape[0] <= 2:
                    continue
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()

            model.eval()
            cur_loss = 0
            with torch.no_grad():
                for i in range(0, len(valid_x_inFit), self.batch_size):
                    # get the inputs
                    inputs = valid_x_inFit[i : i + self.batch_size].to(self.device)
                    labels = valid_y_inFit[i : i + self.batch_size].to(self.device)
                    if inputs.shape[0] == 1:
                        inputs = torch.cat((inputs, inputs, inputs), dim = 0)
                        labels = torch.cat((labels, labels, labels), dim = 0)

                    # forward
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    cur_loss += loss
            # early stop if 3 epochs in a row no loss decrease
            # print(round(time.time()-epoch_start_timer, 2))
            # if time.perf_counter() - epoch_start_timer > budget:
            #     print(f"Stopping training early at epoch {epoch} due to time budget.")
            #     break  # Stop training if budget exceeded
            
            if cur_loss < prev_loss:
                prev_loss = cur_loss
                flag = 0
            else:
                flag += 1
                if flag >= 3:
                    max_epochs.append(epoch)
                    break

        # print(np.max(max_epochs))
        print("evaluating...")
        model.eval()
        with torch.no_grad():
            outputs = model(valid_x_inFit.to(self.device))
            _, predicted = torch.max(outputs.data, 1)
            predictions = predicted.cpu().numpy()
        acc = accuracy_score(valid_y, predictions)
        print("accuracy:", acc)

        self.trial_end_time = time.perf_counter()
        valid_probs = self.predict_proba(valid_x_inFit)
        valid_kappa = cohen_kappa_score(valid_y, predictions)
        valid_ece = get_ece(valid_probs, predictions, valid_y)
        with open('smac_results_2h.txt', "a") as f:
            f.write(f"Valid Accuracy: {acc}, Valid Kappa: {valid_kappa}, Valid ECE: {valid_ece}, Time: {self.trial_end_time - self.trial_start_time}\n")
            
        return 1-acc
    
    def predict_proba(self, X):
        # X = X.reshape(-1, 3, 32, 32)
        model = self.model
        model.eval()
        test_probs = []
        with torch.no_grad():
            outputs = model(X.to(self.device))
            test_prob = nn.Softmax(dim=1)(outputs)
            test_probs = test_prob.cpu().numpy()
            return test_probs
        
def plot_trajectory(facades: list[AbstractFacade], BO_file = None) -> None:
    """Plots the trajectory (incumbents) of the optimization process."""
    plt.figure()
    plt.title("Trajectory")
    plt.xlabel("Wallclock time [s]")
    # print(len(facades))
    plt.ylabel("Accuracy")
    print("\nfacades[0]:", facades[0].scenario)
    # print("\nfacades[1]:", facades[1].scenario)
    # plt.ylim(0, 0.4)

    for facade in facades:
        X, Y = [], []
        for item in facade.intensifier.trajectory:
            # Single-objective optimization
            assert len(item.config_ids) == 1
            assert len(item.costs) == 1
            # print(1 - round(item.costs[0], 3))
            y = item.costs[0]
            x = item.walltime
            print(type(item.costs[0]), item.costs[0])
            X.append(x)
            Y.append(1-y)

        plt.plot(X, Y, label=facade.intensifier.__class__.__name__)
        plt.scatter(X, Y, marker="o")

    if BO_file:
        with open(BO_file, "r") as f:
            data = f.readlines()
        bo_accuracy, bo_kappa, bo_ece, bo_time = [], [], [], []

        # Parse the data
        for line in data:
            # Using regular expression to find all the floating point numbers in each line
            if "Time: " in line:
                numbers = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                if numbers:
                    bo_accuracy.append(float(numbers[0]))
                    bo_kappa.append(float(numbers[1]))
                    bo_ece.append(float(numbers[2]))
                    bo_time.append(float(numbers[3]))

        max_bo_accs = np.maximum.accumulate(bo_accuracy)
        bo_cum_time = np.cumsum(bo_time)
        plt.plot(bo_cum_time, max_bo_accs, label='Max BO Accuracies', marker='x')
    

    plt.legend()
    plt.show()

# %%
from line_profiler import LineProfiler
from pathlib import Path
# @timeout(21600)
def main():

    
    CNN32 = CNN32Wrapper()

    facades: list[AbstractFacade] = []
    for intensifier_object in [Hyperband]:
        # Define our environment variables
        
        scenario = Scenario(
            CNN32.configspace,
            walltime_limit=21600,  # After 3600 seconds, we stop the hyperparameter optimization
            output_directory=Path("smac_hyperband_output_budget_6hr_CNN_5l"),
            n_trials=10000,  # Evaluate max 500 different trials
            min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
            # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
            max_budget=1000,  # only for CNN32_5layers, Resnet18
            n_workers=2,
        )


        
        # We want to run five random configurations before starting the optimization.
        initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
        
        # Create our intensifier
        intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
        
        # Create our SMAC object and pass the scenario and the train method
        smac = MFFacade(
            scenario,
            CNN32.fit,
            initial_design=initial_design,
            intensifier=intensifier,
            overwrite=True,
        )
        # print("I fitted!!!!!!!!!!!!!!:", smac)

        # Let's optimize
        print("optimizing...")
        print(type(smac), "|", smac)
        opt_start_time = time.time()
        incumbent = smac.optimize()
        opt_end_time = time.time()
        print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
        print("incumbent:", incumbent)
        # break
        # Get cost of default configuration
        default_cost = smac.validate(CNN32.configspace.get_default_configuration())
        print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")

        # Let's calculate the cost of the incumbent
        incumbent_cost = smac.validate(incumbent)
        print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
        print("appending...")
        facades.append(smac)
        for attr in dir(smac):
            if not attr.startswith('__'):
                print(attr, getattr(smac, attr))
    print("attempting to plot")
    # Let's plot it
    print("facades:", facades)
    # BO_file = "CNN32_5l_BO_results_2h.txt"
    plot_trajectory(facades)

if __name__ == "__main__":
    with open('smac_results_2h.txt', "w") as f:
        pass
    profiler = LineProfiler()
    profiler.add_function(main)
    profiler.enable()

    main()

    profiler.disable()
    profiler.print_stats()
# Out:
# [INFO][abstract_initial_design.py:82] Using `n_configs` and ignoring `n_configs_per_hyperparameter`.
# [INFO][abstract_initial_design.py:147] Using 5 initial design configurations and 0 additional configurations.
# optimizing...
# <class 'smac.facade.multi_fidelity_facade.MultiFidelityFacade'> | <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>
# [INFO][successive_halving.py:164] Successive Halving uses budget type BUDGETS with eta 3, min budget 100, and max budget 1000.
# [INFO][successive_halving.py:323] Number of configs in stage:
# [INFO][successive_halving.py:325] --- Bracket 0: [9, 3, 1]
# [INFO][successive_halving.py:325] --- Bracket 1: [5, 1]
# [INFO][successive_halving.py:325] --- Bracket 2: [3]
# [INFO][successive_halving.py:327] Budgets in stage:
# [INFO][successive_halving.py:329] --- Bracket 0: [111.1111111111111, 333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 1: [333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 2: [1000.0]
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 569,
#   'dampening': 0.9688321588104364,
#   'epochs': 88,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.03832216850492789,
#   'momentum': 0.2619100559835807,
#   'solver': 'sgd',
#   'weight_decay': 0.007126995609048582,
# })
#
# is sgd: True | is adam: False
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 737,
#   'dampening': 0.7911669785745563,
#   'epochs': 69,
#   'learning_rate': 'constant',
#   'lr_init': 0.011423254155608374,
#   'momentum': 0.7664913525398744,
#   'solver': 'sgd',
#   'weight_decay': 0.006859416411328701,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.18346666666666667
# Config: Configuration(values={
#   'batch_size': 624,
#   'epochs': 111,
#   'lr_init': 0.013680095279726922,
#   'solver': 'adam',
#   'weight_decay': 0.0070925432147358365,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.1258
# Config: Configuration(values={
#   'batch_size': 565,
#   'epochs': 117,
#   'lr_init': 0.07098936257405905,
#   'solver': 'adam',
#   'weight_decay': 0.06780227021579836,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.20286666666666667
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.10473333333333333
# Config: Configuration(values={
#   'batch_size': 378,
#   'dampening': 0.660099048291211,
#   'epochs': 69,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.024846338168982397,
#   'momentum': 0.2082787354631025,
#   'solver': 'sgd',
#   'weight_decay': 0.00024365700014641997,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.14126666666666668
# Config: Configuration(values={
#   'batch_size': 334,
#   'dampening': 0.9784900996786339,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.01381635682257479,
#   'momentum': 0.20678798853388633,
#   'solver': 'sgd',
#   'weight_decay': 0.000304739361773639,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.19193333333333334
# Config: Configuration(values={
#   'batch_size': 674,
#   'dampening': 0.15737988780906453,
#   'epochs': 53,
#   'learning_rate': 'constant',
#   'lr_init': 0.008562913278818234,
#   'momentum': 0.6497662935706207,
#   'solver': 'sgd',
#   'weight_decay': 0.0002597459914786609,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.16426666666666667
# Config: Configuration(values={
#   'batch_size': 214,
#   'dampening': 0.8295654584238159,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.043851702560851274,
#   'momentum': 0.9666948703632617,
#   'solver': 'sgd',
#   'weight_decay': 0.002546558192892438,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.136
# Config: Configuration(values={
#   'batch_size': 477,
#   'dampening': 0.9703800140279047,
#   'epochs': 88,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.07765324440734048,
#   'momentum': 0.3511839719913494,
#   'solver': 'sgd',
#   'weight_decay': 0.007126995609048582,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.20466666666666666
# Config: Configuration(values={
#   'batch_size': 306,
#   'dampening': 0.9784900996786339,
#   'epochs': 65,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.01266581802940437,
#   'momentum': 0.3008273971180134,
#   'solver': 'sgd',
#   'weight_decay': 0.000344263854933194,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.20553333333333335
# Config: Configuration(values={
#   'batch_size': 137,
#   'dampening': 0.9699352160744289,
#   'epochs': 66,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.027933892376955788,
#   'momentum': 0.6385144919013948,
#   'solver': 'sgd',
#   'weight_decay': 0.0005275410696979882,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.16926666666666668
# [INFO][smbo.py:327] Configuration budget is exhausted:
# [INFO][smbo.py:328] --- Remaining wallclock time: -1654.1625800132751
# [INFO][smbo.py:329] --- Remaining cpu time: inf
# [INFO][smbo.py:330] --- Remaining trials: 9987
# Config: Configuration(values={
#   'batch_size': 596,
#   'dampening': 0.5442244418721852,
#   'epochs': 117,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.07098936257405905,
#   'momentum': 0.6587091095649652,
#   'solver': 'sgd',
#   'weight_decay': 0.027820242755593517,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.19593333333333332
# evaluating...
# 2024-05-12 19:54:32,302 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.62 GiB -- Worker memory limit: 8.00 GiB
# accuracy: 0.2256
# 2024-05-12 19:55:21,599 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.61 GiB -- Worker memory limit: 8.00 GiB
# opt execution time: 19391.64567923546 seconds
# incumbent: None
# Config: Configuration(values={
#   'batch_size': 520,
#   'dampening': 0.495,
#   'epochs': 75,
#   'learning_rate': 'constant',
#   'lr_init': 0.01,
#   'momentum': 0.495,
#   'solver': 'sgd',
#   'weight_decay': 0.0031622777,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.16253333333333334
# Default cost (Hyperband): 0.8374666666666667
# Config: None
# Incumbent cost (Hyperband): inf
# appending...
# _acquisition_function <smac.acquisition.function.expected_improvement.EI object at 0x7fd7b17f8eb0>
# _acquisition_maximizer <smac.acquisition.maximizer.local_and_random_search.LocalAndSortedRandomSearch object at 0x7fcef01228e0>
# _callbacks []
# _config_selector <smac.main.config_selector.ConfigSelector object at 0x7fcef01226d0>
# _get_optimizer <bound method AbstractFacade._get_optimizer of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# _get_signature_arguments <bound method AbstractFacade._get_signature_arguments of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# _initial_design <smac.initial_design.random_design.RandomInitialDesign object at 0x7fcef0122880>
# _intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fcef0122580>
# _model <smac.model.random_forest.random_forest.RandomForest object at 0x7fd7b17f8880>
# _multi_objective_algorithm None
# _optimizer <smac.main.smbo.SMBO object at 0x7fd7a8a19610>
# _overwrite True
# _random_design <smac.random_design.probability_design.ProbabilityRandomDesign object at 0x7fcef0122dc0>
# _runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fcef0122640>
# _runhistory_encoder <smac.runhistory.encoder.log_scaled_encoder.RunHistoryLogScaledEncoder object at 0x7fcef0122b80>
# _runner <smac.runner.dask_runner.DaskParallelRunner object at 0x7fcef01227f0>
# _scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='1691167d71f5c4229a7bfc9729adde33', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_5l/1691167d71f5c4229a7bfc9729adde33/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# _update_dependencies <bound method AbstractFacade._update_dependencies of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# _validate <bound method AbstractFacade._validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# ask <bound method AbstractFacade.ask of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# get_acquisition_function <function HyperparameterOptimizationFacade.get_acquisition_function at 0x7fd7a777bf70>
# get_acquisition_maximizer <function HyperparameterOptimizationFacade.get_acquisition_maximizer at 0x7fd7a7782040>
# get_config_selector <function AbstractFacade.get_config_selector at 0x7fd7a7715670>
# get_initial_design <function MultiFidelityFacade.get_initial_design at 0x7fd7a7782670>
# get_intensifier <function MultiFidelityFacade.get_intensifier at 0x7fd7a77825e0>
# get_model <function HyperparameterOptimizationFacade.get_model at 0x7fd7a777bee0>
# get_multi_objective_algorithm <function HyperparameterOptimizationFacade.get_multi_objective_algorithm at 0x7fd7a7782280>
# get_random_design <function HyperparameterOptimizationFacade.get_random_design at 0x7fd7a77821f0>
# get_runhistory_encoder <function HyperparameterOptimizationFacade.get_runhistory_encoder at 0x7fd7a7782310>
# intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fcef0122580>
# meta {'facade': {'name': 'MultiFidelityFacade'}, 'runner': {'name': 'DaskParallelRunner'}, 'model': {'name': 'RandomForest', 'types': [0, 0, 0, 2, 0, 4, 0, 0], 'bounds': [(0, 1.0), (0, 1.0), (0, 1.0), (2, nan), (-1.0, 1.0), (4, nan), (-1.0, 1.0), (-1.0, 1.0)], 'pca_components': 7, 'n_trees': 10, 'n_points_per_tree': -1, 'ratio_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 1048576, 'eps_purity': 1e-08, 'max_nodes': 1048576, 'bootstrapping': True}, 'acquisition_maximizer': {'name': 'LocalAndSortedRandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 10000, 'seed': 0, 'random_search': {'name': 'RandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0}, 'local_search': {'name': 'LocalSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0, 'max_steps': None, 'n_steps_plateau_walk': 10, 'vectorization_min_obtain': 2, 'vectorization_max_obtain': 64}}, 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'intensifier': {'name': 'Hyperband', 'max_incumbents': 10, 'seed': 0, 'eta': 3, 'instance_seed_order': 'shuffle_once', 'incumbent_selection': 'highest_budget'}, 'initial_design': {'name': 'RandomInitialDesign', 'n_configs': 5, 'n_configs_per_hyperparameter': 10, 'additional_configs': [], 'seed': 0}, 'random_design': {'name': 'ProbabilityRandomDesign', 'seed': 0, 'probability': 0.2}, 'runhistory_encoder': {'name': 'RunHistoryLogScaledEncoder', 'considered_states': [<StatusType.SUCCESS: 1>, <StatusType.CRASHED: 2>, <StatusType.MEMORYOUT: 4>], 'lower_budget_states': [], 'scale_percentage': 5, 'seed': 0}, 'multi_objective_algorithm': None, 'config_selector': {'name': 'ConfigSelector', 'retrain_after': 8, 'retries': 16, 'min_trials': 1}, 'version': '2.0.2'}
# optimize <bound method AbstractFacade.optimize of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# optimizer <smac.main.smbo.SMBO object at 0x7fd7a8a19610>
# runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fcef0122640>
# scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='1691167d71f5c4229a7bfc9729adde33', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_5l/1691167d71f5c4229a7bfc9729adde33/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# tell <bound method AbstractFacade.tell of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# validate <bound method AbstractFacade.validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>>
# attempting to plot
# facades: [<smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcef01229a0>]
#
# facades[0]: Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='1691167d71f5c4229a7bfc9729adde33', output_directory=PosixPath('smac_hyperband_output_budget_4hr_CNN_5l/1691167d71f5c4229a7bfc9729adde33/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# Timer unit: 1e-09 s
#
# Total time: 19712.5 s
# File: /var/folders/w0/pq4q2kj50fvdt6t_4y4gqfvw0000gn/T/ipykernel_43860/3540217503.py
# Function: main at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def main():
#      5
#      6
#      7         1    3162000.0    3e+06      0.0      CNN32 = CNN32Wrapper()
#      8
#      9         1          0.0      0.0      0.0      facades: list[AbstractFacade] = []
#     10         2       2000.0   1000.0      0.0      for intensifier_object in [Hyperband]:
#     11                                                   # Define our environment variables
#     12
#     13         2      28000.0  14000.0      0.0          scenario = Scenario(
#     14         1    1025000.0    1e+06      0.0              CNN32.configspace,
#     15         1          0.0      0.0      0.0              walltime_limit=14400,  # After 3600 seconds, we stop the hyperparameter optimization
#     16         1      36000.0  36000.0      0.0              output_directory=Path("smac_hyperband_output_budget_4hr_CNN_5l"),
#     17         1          0.0      0.0      0.0              n_trials=10000,  # Evaluate max 500 different trials
#     18         1          0.0      0.0      0.0              min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
#     19                                                       # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
#     20         1          0.0      0.0      0.0              max_budget=1000,  # only for CNN32_5layers, Resnet18
#     21         1          0.0      0.0      0.0              n_workers=2,
#     22                                                   )
#     23
#     24
#     25
#     26                                                   # We want to run five random configurations before starting the optimization.
#     27         1     901000.0 901000.0      0.0          initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
#     28
#     29                                                   # Create our intensifier
#     30         1     253000.0 253000.0      0.0          intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
#     31
#     32                                                   # Create our SMAC object and pass the scenario and the train method
#     33         2 1285734000.0    6e+08      0.0          smac = MFFacade(
#     34         1          0.0      0.0      0.0              scenario,
#     35         1       1000.0   1000.0      0.0              CNN32.fit,
#     36         1       1000.0   1000.0      0.0              initial_design=initial_design,
#     37         1          0.0      0.0      0.0              intensifier=intensifier,
#     38         1          0.0      0.0      0.0              overwrite=True,
#     39                                                   )
#     40                                                   # print("I fitted!!!!!!!!!!!!!!:", smac)
#     41
#     42                                                   # Let's optimize
#     43         1      51000.0  51000.0      0.0          print("optimizing...")
#     44         1      17000.0  17000.0      0.0          print(type(smac), "|", smac)
#     45         1          0.0      0.0      0.0          opt_start_time = time.time()
#     46         1        2e+13    2e+13     98.4          incumbent = smac.optimize()
#     47         1       7000.0   7000.0      0.0          opt_end_time = time.time()
#     48         1     178000.0 178000.0      0.0          print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
#     49         1       9000.0   9000.0      0.0          print("incumbent:", incumbent)
#     50                                                   # break
#     51                                                   # Get cost of default configuration
#     52         1        3e+11    3e+11      1.6          default_cost = smac.validate(CNN32.configspace.get_default_configuration())
#     53         1     314000.0 314000.0      0.0          print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")
#     54
#     55                                                   # Let's calculate the cost of the incumbent
#     56         1  983067000.0    1e+09      0.0          incumbent_cost = smac.validate(incumbent)
#     57         1     120000.0 120000.0      0.0          print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
#     58         1       5000.0   5000.0      0.0          print("appending...")
#     59         1       1000.0   1000.0      0.0          facades.append(smac)
#     60        64     113000.0   1765.6      0.0          for attr in dir(smac):
#     61        63      25000.0    396.8      0.0              if not attr.startswith('__'):
#     62        37    2373000.0  64135.1      0.0                  print(attr, getattr(smac, attr))
#     63         1       4000.0   4000.0      0.0      print("attempting to plot")
#     64                                               # Let's plot it
#     65         1       8000.0   8000.0      0.0      print("facades:", facades)
#     66                                               # BO_file = "CNN32_5l_BO_results_2h.txt"
#     67         1  202861000.0    2e+08      0.0      plot_trajectory(facades)

# %%
class CNN32Wrapper(BaseEstimator):
    def __init__(self, criterion = nn.CrossEntropyLoss()):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = resnet.to(self.device)
        self.criterion = criterion
        self.lr = None
        self.batch_size = None
        self.epochs = None
        self.optimizer = None

    @property
    def configspace(self)-> ConfigurationSpace:
        cs = ConfigurationSpace()
        lr_init = Float("lr_init", (0.00001, 0.1), log=True)
        learning_rate = Categorical("learning_rate", ["constant", "invscaling", "adaptive"], default="constant")
        solver = Categorical("solver", ["sgd", "adam"])
        batch_size = Integer("batch_size", (16, 1024))
        epochs = Integer("epochs", (30, 160))
        cs.add_hyperparameters([lr_init, learning_rate, solver, batch_size, epochs])

        use_lr = EqualsCondition(child=learning_rate, parent=solver, value="sgd")
        cs.add_conditions([use_lr])

        weight_decay = Float("weight_decay", (0.0001, 0.1), log=True)
        momentum = Float("momentum", (0, 0.99))
        dampening = Float("dampening", (0, 0.99))
        cs.add_hyperparameters([weight_decay, momentum, dampening])

        weight_decay_condition = InCondition(child=weight_decay, parent=solver, values=["sgd", "adam"])
        momentum_condition = InCondition(child=momentum, parent=solver, values=["sgd"])
        dampening_condition = InCondition(child=dampening, parent=solver, values=["sgd"])
        cs.add_conditions([use_lr, weight_decay_condition, momentum_condition, dampening_condition])

        return cs
    
    def fit(self, config: Configuration, seed: int = 0, budget: int = 250) -> float: 
        self.trial_start_time = time.perf_counter()

        print("Config:", config)
        # print(time.time())
        epoch_start_timer = time.perf_counter()
        # print("okay here?")
        max_epochs = [0]
        # print("what abt here?")

        X = torch.tensor(train_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        y = torch.tensor(train_y, dtype=torch.long)
        valid_x_inFit = torch.tensor(valid_x.reshape(-1, 3, 32, 32), dtype=torch.float32)
        valid_y_inFit = torch.tensor(valid_y, dtype=torch.long)


        # ### only for resnet:
        # X = X.repeat(1, 3, 1, 1)
        # valid_x_inFit = valid_x_inFit.repeat(1, 3, 1, 1)


        # print("so far so good")
        # print("Model:", self.model)
        model = self.model
        # print("break1")
        # print("Criterion:", self.criterion)
        criterion = self.criterion

        self.lr = config.get('lr_init')
        # print("lr:", self.lr)
        self.epochs = config.get('epochs')
        # print("epochs:", self.epochs)
        self.batch_size = config.get('batch_size')
        # print("batch_size:", self.batch_size)
        # print("solver type:", type(self.sovler))
        solver_name = config.get('solver', 'sgd')
        # print("solver_name:", solver_name, type(solver_name))
        momentum = config.get('momentum', 0.9)
        weight_decay = config.get('weight_decay', 0.9)
        dampening = config.get('dampening', 0.9)
        print("is sgd:", solver_name=='sgd', "| is adam:", solver_name=='adam')
        # print(self.model.parameters())
        if solver_name == 'sgd':
            # optimizer_args = {
            #     'lr': self.lr,
            #     'momentum': config.get('momentum', 0),
            #     'weight_decay': config.get('weight_decay', 0),
            #     'dampening': config.get('dampening', 0)
            # }
            self.optimizer = optim.SGD(self.model.parameters(), lr=self.lr, momentum=momentum, weight_decay=weight_decay, dampening=dampening)

        elif solver_name == 'adam':
            # optimizer_args = {
            #     'lr': self.lr,
            #     'weight_decay': config.get('weight_decay', 0) 
            # }
            self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr, weight_decay=weight_decay)

        else:
            raise ValueError(f"Unknown optimizer: {solver_name}")
        # print("solver type:", type(self.optimizer))
        # print("solver:", self.optimizer)
        prev_loss = float("inf")
        flag = 0

        for epoch in range(self.epochs):
            model.train()
            for i in range(0, len(X), self.batch_size):
                # print(type(X), type(y))
                inputs = X[i : i + self.batch_size].to(self.device)
                labels = y[i : i + self.batch_size].to(self.device)
                self.optimizer.zero_grad()
                if inputs.shape[0] <= 2:
                    continue
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()

            model.eval()
            cur_loss = 0
            with torch.no_grad():
                for i in range(0, len(valid_x_inFit), self.batch_size):
                    # get the inputs
                    inputs = valid_x_inFit[i : i + self.batch_size].to(self.device)
                    labels = valid_y_inFit[i : i + self.batch_size].to(self.device)
                    if inputs.shape[0] == 1:
                        inputs = torch.cat((inputs, inputs, inputs), dim = 0)
                        labels = torch.cat((labels, labels, labels), dim = 0)

                    # forward
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    cur_loss += loss
            # early stop if 3 epochs in a row no loss decrease
            # print(round(time.time()-epoch_start_timer, 2))
            # if time.perf_counter() - epoch_start_timer > budget:
            #     print(f"Stopping training early at epoch {epoch} due to time budget.")
            #     break  # Stop training if budget exceeded
            
            if cur_loss < prev_loss:
                prev_loss = cur_loss
                flag = 0
            else:
                flag += 1
                if flag >= 3:
                    max_epochs.append(epoch)
                    break

        # print(np.max(max_epochs))
        print("evaluating...")
        model.eval()
        with torch.no_grad():
            outputs = model(valid_x_inFit.to(self.device))
            _, predicted = torch.max(outputs.data, 1)
            predictions = predicted.cpu().numpy()
        acc = accuracy_score(valid_y, predictions)
        print("accuracy:", acc)

        self.trial_end_time = time.perf_counter()
        valid_probs = self.predict_proba(valid_x_inFit)
        valid_kappa = cohen_kappa_score(valid_y, predictions)
        valid_ece = get_ece(valid_probs, predictions, valid_y)
        with open('smac_results_2h.txt', "a") as f:
            f.write(f"Valid Accuracy: {acc}, Valid Kappa: {valid_kappa}, Valid ECE: {valid_ece}, Time: {self.trial_end_time - self.trial_start_time}\n")
            
        return 1-acc
    
    def predict_proba(self, X):
        # X = X.reshape(-1, 3, 32, 32)
        model = self.model
        model.eval()
        test_probs = []
        with torch.no_grad():
            outputs = model(X.to(self.device))
            test_prob = nn.Softmax(dim=1)(outputs)
            test_probs = test_prob.cpu().numpy()
            return test_probs
        
def plot_trajectory(facades: list[AbstractFacade], BO_file = None) -> None:
    """Plots the trajectory (incumbents) of the optimization process."""
    plt.figure()
    plt.title("Trajectory")
    plt.xlabel("Wallclock time [s]")
    # print(len(facades))
    plt.ylabel("Accuracy")
    print("\nfacades[0]:", facades[0].scenario)
    # print("\nfacades[1]:", facades[1].scenario)
    # plt.ylim(0, 0.4)

    for facade in facades:
        X, Y = [], []
        for item in facade.intensifier.trajectory:
            # Single-objective optimization
            assert len(item.config_ids) == 1
            assert len(item.costs) == 1
            # print(1 - round(item.costs[0], 3))
            y = item.costs[0]
            x = item.walltime
            print(type(item.costs[0]), item.costs[0])
            X.append(x)
            Y.append(1-y)

        plt.plot(X, Y, label=facade.intensifier.__class__.__name__)
        plt.scatter(X, Y, marker="o")

    if BO_file:
        with open(BO_file, "r") as f:
            data = f.readlines()
        bo_accuracy, bo_kappa, bo_ece, bo_time = [], [], [], []

        # Parse the data
        for line in data:
            # Using regular expression to find all the floating point numbers in each line
            if "Time: " in line:
                numbers = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                if numbers:
                    bo_accuracy.append(float(numbers[0]))
                    bo_kappa.append(float(numbers[1]))
                    bo_ece.append(float(numbers[2]))
                    bo_time.append(float(numbers[3]))

        max_bo_accs = np.maximum.accumulate(bo_accuracy)
        bo_cum_time = np.cumsum(bo_time)
        plt.plot(bo_cum_time, max_bo_accs, label='Max BO Accuracies', marker='x')
    

    plt.legend()
    plt.show()

# %%
from line_profiler import LineProfiler
from pathlib import Path
# @timeout(21600)
def main():

    
    CNN32 = CNN32Wrapper()

    facades: list[AbstractFacade] = []
    for intensifier_object in [Hyperband]:
        # Define our environment variables
        
        scenario = Scenario(
            CNN32.configspace,
            walltime_limit=21600,  # After 3600 seconds, we stop the hyperparameter optimization
            output_directory=Path("smac_hyperband_output_budget_6hr_Resnet"),
            n_trials=10000,  # Evaluate max 500 different trials
            min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
            # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
            max_budget=1000,  # only for CNN32_5layers, Resnet18
            n_workers=2,
        )


        
        # We want to run five random configurations before starting the optimization.
        initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
        
        # Create our intensifier
        intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
        
        # Create our SMAC object and pass the scenario and the train method
        smac = MFFacade(
            scenario,
            CNN32.fit,
            initial_design=initial_design,
            intensifier=intensifier,
            overwrite=True,
        )
        # print("I fitted!!!!!!!!!!!!!!:", smac)

        # Let's optimize
        print("optimizing...")
        print(type(smac), "|", smac)
        opt_start_time = time.time()
        incumbent = smac.optimize()
        opt_end_time = time.time()
        print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
        print("incumbent:", incumbent)
        # break
        # Get cost of default configuration
        default_cost = smac.validate(CNN32.configspace.get_default_configuration())
        print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")

        # Let's calculate the cost of the incumbent
        incumbent_cost = smac.validate(incumbent)
        print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
        print("appending...")
        facades.append(smac)
        for attr in dir(smac):
            if not attr.startswith('__'):
                print(attr, getattr(smac, attr))
    print("attempting to plot")
    # Let's plot it
    print("facades:", facades)
    # BO_file = "CNN32_5l_BO_results_2h.txt"
    plot_trajectory(facades)

if __name__ == "__main__":
    with open('smac_results_2h.txt', "w") as f:
        pass
    profiler = LineProfiler()
    profiler.add_function(main)
    profiler.enable()

    main()

    profiler.disable()
    profiler.print_stats()
# Out:
# [INFO][abstract_initial_design.py:82] Using `n_configs` and ignoring `n_configs_per_hyperparameter`.
# [INFO][abstract_initial_design.py:147] Using 5 initial design configurations and 0 additional configurations.
# optimizing...
# <class 'smac.facade.multi_fidelity_facade.MultiFidelityFacade'> | <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>
# [INFO][successive_halving.py:164] Successive Halving uses budget type BUDGETS with eta 3, min budget 100, and max budget 1000.
# [INFO][successive_halving.py:323] Number of configs in stage:
# [INFO][successive_halving.py:325] --- Bracket 0: [9, 3, 1]
# [INFO][successive_halving.py:325] --- Bracket 1: [5, 1]
# [INFO][successive_halving.py:325] --- Bracket 2: [3]
# [INFO][successive_halving.py:327] Budgets in stage:
# [INFO][successive_halving.py:329] --- Bracket 0: [111.1111111111111, 333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 1: [333.3333333333333, 1000.0]
# [INFO][successive_halving.py:329] --- Bracket 2: [1000.0]
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 569,
#   'dampening': 0.9688321588104364,
#   'epochs': 88,
#   'learning_rate': 'invscaling',
#   'lr_init': 0.03832216850492789,
#   'momentum': 0.2619100559835807,
#   'solver': 'sgd',
#   'weight_decay': 0.007126995609048582,
# })
#
# is sgd: True | is adam: False
# [INFO][smbo.py:319] Finished 0 trials.
# Config: Configuration(values={
#   'batch_size': 737,
#   'dampening': 0.7911669785745563,
#   'epochs': 69,
#   'learning_rate': 'constant',
#   'lr_init': 0.011423254155608374,
#   'momentum': 0.7664913525398744,
#   'solver': 'sgd',
#   'weight_decay': 0.006859416411328701,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3406
# Config: Configuration(values={
#   'batch_size': 624,
#   'epochs': 111,
#   'lr_init': 0.013680095279726922,
#   'solver': 'adam',
#   'weight_decay': 0.0070925432147358365,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.24873333333333333
# Config: Configuration(values={
#   'batch_size': 565,
#   'epochs': 117,
#   'lr_init': 0.07098936257405905,
#   'solver': 'adam',
#   'weight_decay': 0.06780227021579836,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.3362
# Config: Configuration(values={
#   'batch_size': 443,
#   'epochs': 64,
#   'lr_init': 0.0013869861245357324,
#   'solver': 'adam',
#   'weight_decay': 0.011103525577197588,
# })
#
# is sgd: False | is adam: True
# evaluating...
# accuracy: 0.10053333333333334
# Config: Configuration(values={
#   'batch_size': 378,
#   'dampening': 0.660099048291211,
#   'epochs': 69,
#   'learning_rate': 'adaptive',
#   'lr_init': 0.024846338168982397,
#   'momentum': 0.2082787354631025,
#   'solver': 'sgd',
#   'weight_decay': 0.00024365700014641997,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3429333333333333
# Config: Configuration(values={
#   'batch_size': 334,
#   'dampening': 0.9784900996786339,
#   'epochs': 63,
#   'learning_rate': 'constant',
#   'lr_init': 0.01381635682257479,
#   'momentum': 0.20678798853388633,
#   'solver': 'sgd',
#   'weight_decay': 0.000304739361773639,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.432
# [INFO][smbo.py:327] Configuration budget is exhausted:
# [INFO][smbo.py:328] --- Remaining wallclock time: -461.66376209259033
# [INFO][smbo.py:329] --- Remaining cpu time: inf
# [INFO][smbo.py:330] --- Remaining trials: 9992
# Config: Configuration(values={
#   'batch_size': 674,
#   'dampening': 0.15737988780906453,
#   'epochs': 53,
#   'learning_rate': 'constant',
#   'lr_init': 0.008562913278818234,
#   'momentum': 0.6497662935706207,
#   'solver': 'sgd',
#   'weight_decay': 0.0002597459914786609,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3492
# evaluating...
# accuracy: 0.3276
# opt execution time: 35112.11740422249 seconds
# incumbent: None
# Config: Configuration(values={
#   'batch_size': 520,
#   'dampening': 0.495,
#   'epochs': 75,
#   'learning_rate': 'constant',
#   'lr_init': 0.01,
#   'momentum': 0.495,
#   'solver': 'sgd',
#   'weight_decay': 0.0031622777,
# })
#
# is sgd: True | is adam: False
# evaluating...
# accuracy: 0.3424
# Default cost (Hyperband): 0.6576
# Config: None
# Incumbent cost (Hyperband): inf
# appending...
# _acquisition_function <smac.acquisition.function.expected_improvement.EI object at 0x7fcef0122ee0>
# _acquisition_maximizer <smac.acquisition.maximizer.local_and_random_search.LocalAndSortedRandomSearch object at 0x7fcff0609610>
# _callbacks []
# _config_selector <smac.main.config_selector.ConfigSelector object at 0x7fcff06097f0>
# _get_optimizer <bound method AbstractFacade._get_optimizer of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# _get_signature_arguments <bound method AbstractFacade._get_signature_arguments of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# _initial_design <smac.initial_design.random_design.RandomInitialDesign object at 0x7fcef0122ca0>
# _intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fd790aa95b0>
# _model <smac.model.random_forest.random_forest.RandomForest object at 0x7fd7a78afa90>
# _multi_objective_algorithm None
# _optimizer <smac.main.smbo.SMBO object at 0x7fd780db5190>
# _overwrite True
# _random_design <smac.random_design.probability_design.ProbabilityRandomDesign object at 0x7fcff06092b0>
# _runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fcff0609670>
# _runhistory_encoder <smac.runhistory.encoder.log_scaled_encoder.RunHistoryLogScaledEncoder object at 0x7fcff06096a0>
# _runner <smac.runner.dask_runner.DaskParallelRunner object at 0x7fd7802bff40>
# _scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='ebf4b9522bcc1e1dd12be83eed173ed9', output_directory=PosixPath('smac_hyperband_output_budget_4hr_Resnet/ebf4b9522bcc1e1dd12be83eed173ed9/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# _update_dependencies <bound method AbstractFacade._update_dependencies of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# _validate <bound method AbstractFacade._validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# ask <bound method AbstractFacade.ask of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# get_acquisition_function <function HyperparameterOptimizationFacade.get_acquisition_function at 0x7fd7a777bf70>
# get_acquisition_maximizer <function HyperparameterOptimizationFacade.get_acquisition_maximizer at 0x7fd7a7782040>
# get_config_selector <function AbstractFacade.get_config_selector at 0x7fd7a7715670>
# get_initial_design <function MultiFidelityFacade.get_initial_design at 0x7fd7a7782670>
# get_intensifier <function MultiFidelityFacade.get_intensifier at 0x7fd7a77825e0>
# get_model <function HyperparameterOptimizationFacade.get_model at 0x7fd7a777bee0>
# get_multi_objective_algorithm <function HyperparameterOptimizationFacade.get_multi_objective_algorithm at 0x7fd7a7782280>
# get_random_design <function HyperparameterOptimizationFacade.get_random_design at 0x7fd7a77821f0>
# get_runhistory_encoder <function HyperparameterOptimizationFacade.get_runhistory_encoder at 0x7fd7a7782310>
# intensifier <smac.intensifier.hyperband.Hyperband object at 0x7fd790aa95b0>
# meta {'facade': {'name': 'MultiFidelityFacade'}, 'runner': {'name': 'DaskParallelRunner'}, 'model': {'name': 'RandomForest', 'types': [0, 0, 0, 2, 0, 4, 0, 0], 'bounds': [(0, 1.0), (0, 1.0), (0, 1.0), (2, nan), (-1.0, 1.0), (4, nan), (-1.0, 1.0), (-1.0, 1.0)], 'pca_components': 7, 'n_trees': 10, 'n_points_per_tree': -1, 'ratio_features': 1.0, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 1048576, 'eps_purity': 1e-08, 'max_nodes': 1048576, 'bootstrapping': True}, 'acquisition_maximizer': {'name': 'LocalAndSortedRandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 10000, 'seed': 0, 'random_search': {'name': 'RandomSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0}, 'local_search': {'name': 'LocalSearch', 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'challengers': 5000, 'seed': 0, 'max_steps': None, 'n_steps_plateau_walk': 10, 'vectorization_min_obtain': 2, 'vectorization_max_obtain': 64}}, 'acquisition_function': {'name': 'EI', 'xi': 0.0, 'log': True}, 'intensifier': {'name': 'Hyperband', 'max_incumbents': 10, 'seed': 0, 'eta': 3, 'instance_seed_order': 'shuffle_once', 'incumbent_selection': 'highest_budget'}, 'initial_design': {'name': 'RandomInitialDesign', 'n_configs': 5, 'n_configs_per_hyperparameter': 10, 'additional_configs': [], 'seed': 0}, 'random_design': {'name': 'ProbabilityRandomDesign', 'seed': 0, 'probability': 0.2}, 'runhistory_encoder': {'name': 'RunHistoryLogScaledEncoder', 'considered_states': [<StatusType.SUCCESS: 1>, <StatusType.CRASHED: 2>, <StatusType.MEMORYOUT: 4>], 'lower_budget_states': [], 'scale_percentage': 5, 'seed': 0}, 'multi_objective_algorithm': None, 'config_selector': {'name': 'ConfigSelector', 'retrain_after': 8, 'retries': 16, 'min_trials': 1}, 'version': '2.0.2'}
# optimize <bound method AbstractFacade.optimize of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# optimizer <smac.main.smbo.SMBO object at 0x7fd780db5190>
# runhistory <smac.runhistory.runhistory.RunHistory object at 0x7fcff0609670>
# scenario Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='ebf4b9522bcc1e1dd12be83eed173ed9', output_directory=PosixPath('smac_hyperband_output_budget_4hr_Resnet/ebf4b9522bcc1e1dd12be83eed173ed9/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# tell <bound method AbstractFacade.tell of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# validate <bound method AbstractFacade.validate of <smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>>
# attempting to plot
# facades: [<smac.facade.multi_fidelity_facade.MultiFidelityFacade object at 0x7fcff0609460>]
#
# facades[0]: Scenario(configspace=Configuration space object:
#   Hyperparameters:
#     batch_size, Type: UniformInteger, Range: [16, 1024], Default: 520
#     dampening, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     epochs, Type: UniformInteger, Range: [30, 120], Default: 75
#     learning_rate, Type: Categorical, Choices: {constant, invscaling, adaptive}, Default: constant
#     lr_init, Type: UniformFloat, Range: [0.001, 0.1], Default: 0.01, on log-scale
#     momentum, Type: UniformFloat, Range: [0.0, 0.99], Default: 0.495
#     solver, Type: Categorical, Choices: {sgd, adam}, Default: sgd
#     weight_decay, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#   Conditions:
#     dampening | solver in {'sgd'}
#     learning_rate | solver == 'sgd'
#     momentum | solver in {'sgd'}
#     weight_decay | solver in {'sgd', 'adam'}
# , name='ebf4b9522bcc1e1dd12be83eed173ed9', output_directory=PosixPath('smac_hyperband_output_budget_4hr_Resnet/ebf4b9522bcc1e1dd12be83eed173ed9/0'), deterministic=False, objectives='cost', crash_cost=inf, termination_cost_threshold=inf, walltime_limit=14400, cputime_limit=inf, trial_walltime_limit=None, trial_memory_limit=None, n_trials=10000, use_default_config=False, instances=None, instance_features=None, min_budget=100, max_budget=1000, seed=0, n_workers=2)
# Timer unit: 1e-09 s
#
# Total time: 35656.4 s
# File: /var/folders/w0/pq4q2kj50fvdt6t_4y4gqfvw0000gn/T/ipykernel_43860/1181825811.py
# Function: main at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def main():
#      5
#      6
#      7         1    3335000.0    3e+06      0.0      CNN32 = CNN32Wrapper()
#      8
#      9         1          0.0      0.0      0.0      facades: list[AbstractFacade] = []
#     10         2       3000.0   1500.0      0.0      for intensifier_object in [Hyperband]:
#     11                                                   # Define our environment variables
#     12
#     13         2      34000.0  17000.0      0.0          scenario = Scenario(
#     14         1    1461000.0    1e+06      0.0              CNN32.configspace,
#     15         1          0.0      0.0      0.0              walltime_limit=14400,  # After 3600 seconds, we stop the hyperparameter optimization
#     16         1      51000.0  51000.0      0.0              output_directory=Path("smac_hyperband_output_budget_4hr_Resnet"),
#     17         1          0.0      0.0      0.0              n_trials=10000,  # Evaluate max 500 different trials
#     18         1       1000.0   1000.0      0.0              min_budget=100,  # Train the MLP using a hyperparameter configuration for at least 5 epochs
#     19                                                       # max_budget=25,  # Train the MLP using a hyperparameter configuration for at most 25 epochs
#     20         1          0.0      0.0      0.0              max_budget=1000,  # only for CNN32_5layers, Resnet18
#     21         1          0.0      0.0      0.0              n_workers=2,
#     22                                                   )
#     23
#     24
#     25
#     26                                                   # We want to run five random configurations before starting the optimization.
#     27         1     830000.0 830000.0      0.0          initial_design = MFFacade.get_initial_design(scenario, n_configs=5)
#     28
#     29                                                   # Create our intensifier
#     30         1     318000.0 318000.0      0.0          intensifier = intensifier_object(scenario, incumbent_selection="highest_budget")
#     31
#     32                                                   # Create our SMAC object and pass the scenario and the train method
#     33         2 1320690000.0    7e+08      0.0          smac = MFFacade(
#     34         1          0.0      0.0      0.0              scenario,
#     35         1       1000.0   1000.0      0.0              CNN32.fit,
#     36         1       1000.0   1000.0      0.0              initial_design=initial_design,
#     37         1          0.0      0.0      0.0              intensifier=intensifier,
#     38         1       1000.0   1000.0      0.0              overwrite=True,
#     39                                                   )
#     40                                                   # print("I fitted!!!!!!!!!!!!!!:", smac)
#     41
#     42                                                   # Let's optimize
#     43         1      58000.0  58000.0      0.0          print("optimizing...")
#     44         1      18000.0  18000.0      0.0          print(type(smac), "|", smac)
#     45         1       1000.0   1000.0      0.0          opt_start_time = time.time()
#     46         1        4e+13    4e+13     98.5          incumbent = smac.optimize()
#     47         1       9000.0   9000.0      0.0          opt_end_time = time.time()
#     48         1     166000.0 166000.0      0.0          print(f"opt execution time: {opt_end_time - opt_start_time} seconds")
#     49         1       9000.0   9000.0      0.0          print("incumbent:", incumbent)
#     50                                                   # break
#     51                                                   # Get cost of default configuration
#     52         1        5e+11    5e+11      1.5          default_cost = smac.validate(CNN32.configspace.get_default_configuration())
#     53         1     704000.0 704000.0      0.0          print(f"Default cost ({intensifier.__class__.__name__}): {default_cost}")
#     54
#     55                                                   # Let's calculate the cost of the incumbent
#     56         1  987849000.0    1e+09      0.0          incumbent_cost = smac.validate(incumbent)
#     57         1     115000.0 115000.0      0.0          print(f"Incumbent cost ({intensifier.__class__.__name__}): {incumbent_cost}")
#     58         1       5000.0   5000.0      0.0          print("appending...")
#     59         1       1000.0   1000.0      0.0          facades.append(smac)
#     60        64     329000.0   5140.6      0.0          for attr in dir(smac):
#     61        63      29000.0    460.3      0.0              if not attr.startswith('__'):
#     62        37    3770000.0 101891.9      0.0                  print(attr, getattr(smac, attr))
#     63         1       5000.0   5000.0      0.0      print("attempting to plot")
#     64                                               # Let's plot it
#     65         1       9000.0   9000.0      0.0      print("facades:", facades)
#     66                                               # BO_file = "CNN32_5l_BO_results_2h.txt"
#     67         1  249283000.0    2e+08      0.0      plot_trajectory(facades)

# %%
runhistory_path = "smac_hyperband_output_budget_2hr_CNN_5l/3dfdef37a2c720217b5848e4da32ffe9/0/runhistory.json"

with open(runhistory_path, "r") as file:
    runhistory_data_CNN = json.load(file)

print("Length of runhistory_data_CNN:", len(runhistory_data_CNN["data"]))

configs_costs_CNN = []
for entry in runhistory_data_CNN["data"]:
    # print(entry)
    config_id = entry[0]  
    cost = entry[4]  
    configs_costs_CNN.append((entry[0], entry[4]))
    configs_costs_CNN = list(set(configs_costs_CNN))

    # print(f"Config ID: {config_id}, Cost: {cost}")
    if config_id == 44:# or config_id == 21:
        params_CNN = runhistory_data_CNN["configs"][str(config_id)]
        # print(entry)
        print(f"CNN config ID: {config_id}, Cost: {cost}, Parameters: {params_CNN}\n")


min_cost_config_CNN = []
min_cost_config_CNN = sorted(configs_costs_CNN, key=lambda x: x[1])[:5]
print("CNN min 5:")
for config_id, cost in min_cost_config_CNN:
    
    params = runhistory_data_CNN["configs"][str(config_id)]
    print(f"Config ID: {config_id}, Cost: {cost}, Parameters: {params}\n")
file.close()
# Out:
# Length of runhistory_data_CNN: 9
# CNN min 5:
# Config ID: 3, Cost: 0.8436, Parameters: {'batch_size': 624, 'epochs': 111, 'lr_init': 0.013680095279726922, 'solver': 'adam', 'weight_decay': 0.0070925432147358365}
#
# Config ID: 5, Cost: 0.848, Parameters: {'batch_size': 443, 'epochs': 64, 'lr_init': 0.0013869861245357324, 'solver': 'adam', 'weight_decay': 0.011103525577197588}
#
# Config ID: 1, Cost: 0.8734666666666666, Parameters: {'batch_size': 569, 'epochs': 88, 'lr_init': 0.03832216850492789, 'solver': 'sgd', 'dampening': 0.9688321588104364, 'learning_rate': 'invscaling', 'momentum': 0.2619100559835807, 'weight_decay': 0.007126995609048582}
#
# Config ID: 6, Cost: 0.8742666666666666, Parameters: {'batch_size': 378, 'epochs': 69, 'lr_init': 0.024846338168982397, 'solver': 'sgd', 'dampening': 0.660099048291211, 'learning_rate': 'adaptive', 'momentum': 0.2082787354631025, 'weight_decay': 0.00024365700014641997}
#
# Config ID: 2, Cost: 0.8788666666666667, Parameters: {'batch_size': 737, 'epochs': 69, 'lr_init': 0.011423254155608374, 'solver': 'sgd', 'dampening': 0.7911669785745563, 'learning_rate': 'constant', 'momentum': 0.7664913525398744, 'weight_decay': 0.006859416411328701}

# %%
runhistory_path_RES = "smac_hyperband_output_budget_2hr_XGBT/cb99f55e09d035f575c5f944893086b6/0/runhistory.json"

with open(runhistory_path_RES, "r") as file:
    runhistory_data_RES = json.load(file)

print("Length of runhistory data:", len(runhistory_data_RES["data"]))

configs_costs_RES = []
for entry in runhistory_data_RES["data"]:
    config_id = entry[0]  
    cost = entry[4]
    configs_costs_RES.append((entry[0], entry[4]))
    configs_costs_RES = list(set(configs_costs_RES))
    if config_id == 44:
        params = runhistory_data_RES["configs"][str(config_id)]
        # print(entry)
        print(f"Resnet Config ID: {config_id}, Cost: {cost}, Parameters: {params}\n")


min_cost_config_RES = []
min_cost_config_RES = sorted(configs_costs_RES, key=lambda x: x[1])[:5]
print(type(min_cost_config_RES))
print("Resnet min 5:")
for config_id, cost in min_cost_config_RES:
    
    params = runhistory_data_RES["configs"][str(config_id)]
    print(f"Config ID: {config_id}, Cost: {cost}, Parameters: {params}\n")
file.close()
# Out:
# Length of runhistory data: 3
# <class 'list'>
# Resnet min 5:
# Config ID: 2, Cost: 0.4538333333333334, Parameters: {'colsample_bylevel': 0.8006325564606935, 'colsample_bynode': 0.6063110478838847, 'colsample_bytree': 0.6702264438270331, 'gamma': 0.11819655769629316, 'learning_rate': 0.24175598362284983, 'max_depth': 4, 'min_child_weight': 8, 'n_estimators': 773, 'subsample': 0.7185159768996707}
#
# Config ID: 3, Cost: 0.4995666666666667, Parameters: {'colsample_bylevel': 0.7219343632501507, 'colsample_bynode': 0.9242411005474558, 'colsample_bytree': 0.6976311927657526, 'gamma': 0.8493578609931441, 'learning_rate': 0.14382901505335025, 'max_depth': 20, 'min_child_weight': 5, 'n_estimators': 779, 'subsample': 0.8488155979636325}
#
# Config ID: 1, Cost: 0.5049666666666667, Parameters: {'colsample_bylevel': 0.6841694527491273, 'colsample_bynode': 0.7521258791466592, 'colsample_bytree': 0.8542075266578653, 'gamma': 0.17841636973138664, 'learning_rate': 0.2937993192475016, 'max_depth': 14, 'min_child_weight': 3, 'n_estimators': 780, 'subsample': 0.679753950286893}

# %%
test_res = []
test_cnn = []
params_RES = runhistory_data_RES["configs"]
params_CNN = runhistory_data_CNN["configs"]

print(f"length of Res:{len(params_RES)}")
print(f"length of CNN:{len(params_CNN)}")

cnt = 0
i_list = []
for i in range(1, 200):
    try:
        res_params = runhistory_data_RES["configs"][str(i)]
        cnn_params = runhistory_data_CNN["configs"][str(i)]
        print("ID = {}, match_status = {} \n".format(i, res_params == cnn_params))
        if res_params != cnn_params:
            i_list.append(i)
            cnt += 1
        # print(res_params, cnn_params, "\n")
    except KeyError:
        print("KeyError: skipping entry")

print(f"{cnt} pairs not same")
print(f"first difference occured at {min(i_list)}")
# Out:
# length of Res:57
# length of CNN:55
# ID = 1, match_status = True
#
# ID = 2, match_status = True
#
# ID = 3, match_status = True
#
# ID = 4, match_status = True
#
# ID = 5, match_status = True
#
# ID = 6, match_status = True
#
# ID = 7, match_status = True
#
# ID = 8, match_status = True
#
# ID = 9, match_status = True
#
# ID = 10, match_status = False
#
# ID = 11, match_status = False
#
# ID = 12, match_status = False
#
# ID = 13, match_status = False
#
# ID = 14, match_status = False
#
# ID = 15, match_status = False
#
# ID = 16, match_status = False
#
# ID = 17, match_status = False
#
# ID = 18, match_status = True
#
# ID = 19, match_status = True
#
# ID = 20, match_status = True
#
# ID = 21, match_status = True
#
# ID = 22, match_status = True
#
# ID = 23, match_status = True
#
# ID = 24, match_status = True
#
# ID = 25, match_status = True
#
# ID = 26, match_status = True
#
# ID = 27, match_status = True
#
# ID = 28, match_status = True
#
# ID = 29, match_status = True
#
# ID = 30, match_status = True
#
# ID = 31, match_status = True
#
# ID = 32, match_status = True
#
# ID = 33, match_status = True
#
# ID = 34, match_status = True
#
# ID = 35, match_status = False
#
# ID = 36, match_status = True
#
# ID = 37, match_status = False
#
# ID = 38, match_status = False
#
# ID = 39, match_status = False
#
# ID = 40, match_status = False
#
# ID = 41, match_status = False
#
# ID = 42, match_status = False
#
# ID = 43, match_status = False
#
# ID = 44, match_status = True
#
# ID = 45, match_status = False
#
# ID = 46, match_status = False
#
# ID = 47, match_status = False
#
# ID = 48, match_status = False
#
# ID = 49, match_status = False
#
# ID = 50, match_status = False
#
# ID = 51, match_status = False
#
# ID = 52, match_status = False
#
# ID = 53, match_status = True
#
# ID = 54, match_status = False
#
# ID = 55, match_status = False
#
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# KeyError: skipping entry
# 26 pairs not same
# first difference occured at 10
